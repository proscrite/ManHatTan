# %%
import docx 
from io import StringIO
import pandas as pd
import numpy as np
import os
import sys

# %%
sys.path.append('../python_scripts/')
from rashib import *

# %% [markdown]
# # Import file

# %%
from docx import Document

# %%
doc = docx.Document('Notizen aus _Siddhartha_ eine indische Dichtung (German Edition)_.docx')

# %% [markdown]
# ## Read its content: tables of one cell

# %%
for t in doc.tables:
    for r in t.rows:
        for c in r.cells:
            print(c.text)
# Out:
# Siddhartha: eine indische Dichtung (German Edition)
# Hermann Hesse
# Dieses Dokument wird überschrieben, wenn du Änderungen in Play Bücher vornimmst.
# Erstelle eine Kopie dieses Dokuments, bevor du es bearbeitest.

# %%
cell = doc.tables[3].rows[0].cells[0]
text = cell.text
cell.paragraphs[1].style.font
# Document.paragraphs.style.font

# %% [markdown]
# ## Find words highlighted in blue: there is no python interface, need to access xml
# By modifying https://stackoverflow.com/questions/9562671/extracting-highlighted-words-from-word-document-docx-in-python?rq=1
#
# Structure of a filled text:
# ```
# <w:r>
#     <w:rPr>
#         <w:shd w:fill='fde096'> #In this case gold
#     </w:rPr>
#     <w:t> text that is highlighted </w:t>
# </w:r>```

# %%
document = docx.Document(r'Notizen aus _Siddhartha_ eine indische Dichtung (German Edition)_.docx')
words = document.element.xpath('//w:r')
words
# Out:
# [<CT_R '<w:r>' at 0x10a4884a8>,
#  <CT_R '<w:r>' at 0x10d9d94a8>,
#  <CT_R '<w:r>' at 0x10d9d94f8>,
#  <CT_R '<w:r>' at 0x10d9d9548>,
#  <CT_R '<w:r>' at 0x10d9d9598>,
#  <CT_R '<w:r>' at 0x10d9d95e8>,
#  <CT_R '<w:r>' at 0x10d9d92c8>,
#  <CT_R '<w:r>' at 0x10d9d9688>,
#  <CT_R '<w:r>' at 0x10d9d96d8>,
#  <CT_R '<w:r>' at 0x10d9d9728>,
#  <CT_R '<w:r>' at 0x10d9d9778>,
#  <CT_R '<w:r>' at 0x10d9d97c8>,
#  <CT_R '<w:r>' at 0x10d9d9818>,
#  <CT_R '<w:r>' at 0x10d9d9868>,
#  <CT_R '<w:r>' at 0x10d9d98b8>,
#  <CT_R '<w:r>' at 0x10d9d9908>,
#  <CT_R '<w:r>' at 0x10d9d9958>,
#  <CT_R '<w:r>' at 0x10d9d99a8>,
#  <CT_R '<w:r>' at 0x10d9d99f8>,
#  <CT_R '<w:r>' at 0x10d9d9a48>,
#  <CT_R '<w:r>' at 0x10d9d9a98>,
#  <CT_R '<w:r>' at 0x10d9d9ae8>,
#  <CT_R '<w:r>' at 0x10d9d9db8>,
#  <CT_R '<w:r>' at 0x10d9d9d18>,
#  <CT_R '<w:r>' at 0x10d9d9e08>,
#  <CT_R '<w:r>' at 0x10d9d9e58>,
#  <CT_R '<w:r>' at 0x10d9d9ea8>,
#  <CT_R '<w:r>' at 0x10d9d9ef8>,
#  <CT_R '<w:r>' at 0x10d9d9f48>,
#  <CT_R '<w:r>' at 0x10d9d9f98>,
#  <CT_R '<w:r>' at 0x10e0271d8>,
#  <CT_R '<w:r>' at 0x10e027188>,
#  <CT_R '<w:r>' at 0x10e027548>,
#  <CT_R '<w:r>' at 0x10e0274a8>,
#  <CT_R '<w:r>' at 0x10e027048>,
#  <CT_R '<w:r>' at 0x10e027098>,
#  <CT_R '<w:r>' at 0x10e0270e8>,
#  <CT_R '<w:r>' at 0x10e027138>,
#  <CT_R '<w:r>' at 0x10e027228>,
#  <CT_R '<w:r>' at 0x10e027278>,
#  <CT_R '<w:r>' at 0x10e0272c8>,
#  <CT_R '<w:r>' at 0x10e027318>,
#  <CT_R '<w:r>' at 0x10e027368>,
#  <CT_R '<w:r>' at 0x10e0273b8>,
#  <CT_R '<w:r>' at 0x10e027408>,
#  <CT_R '<w:r>' at 0x10e027458>,
#  <CT_R '<w:r>' at 0x116184548>,
#  <CT_R '<w:r>' at 0x116184368>,
#  <CT_R '<w:r>' at 0x116184598>,
#  <CT_R '<w:r>' at 0x1161b56d8>,
#  <CT_R '<w:r>' at 0x1161b5728>,
#  <CT_R '<w:r>' at 0x1161b5778>,
#  <CT_R '<w:r>' at 0x1161b57c8>,
#  <CT_R '<w:r>' at 0x1161b5818>,
#  <CT_R '<w:r>' at 0x1161b5868>,
#  <CT_R '<w:r>' at 0x1161b58b8>,
#  <CT_R '<w:r>' at 0x1161b5908>,
#  <CT_R '<w:r>' at 0x1161b5958>,
#  <CT_R '<w:r>' at 0x1161b59a8>,
#  <CT_R '<w:r>' at 0x1161b59f8>,
#  <CT_R '<w:r>' at 0x1161b5a48>,
#  <CT_R '<w:r>' at 0x1161b5a98>,
#  <CT_R '<w:r>' at 0x1161b5ae8>,
#  <CT_R '<w:r>' at 0x1161b5b38>,
#  <CT_R '<w:r>' at 0x1161b5b88>,
#  <CT_R '<w:r>' at 0x1161b5bd8>,
#  <CT_R '<w:r>' at 0x1161b5c28>,
#  <CT_R '<w:r>' at 0x1161b5c78>,
#  <CT_R '<w:r>' at 0x1161b5cc8>,
#  <CT_R '<w:r>' at 0x1161b5d18>,
#  <CT_R '<w:r>' at 0x1161b5d68>,
#  <CT_R '<w:r>' at 0x1161b5db8>,
#  <CT_R '<w:r>' at 0x1161b5e08>,
#  <CT_R '<w:r>' at 0x1161b5e58>,
#  <CT_R '<w:r>' at 0x1161b5ea8>,
#  <CT_R '<w:r>' at 0x1161b5ef8>,
#  <CT_R '<w:r>' at 0x1161b5f48>,
#  <CT_R '<w:r>' at 0x1161b5f98>,
#  <CT_R '<w:r>' at 0x10e01d048>,
#  <CT_R '<w:r>' at 0x10e01d098>,
#  <CT_R '<w:r>' at 0x10e01d0e8>,
#  <CT_R '<w:r>' at 0x10e01d138>,
#  <CT_R '<w:r>' at 0x10e01d188>,
#  <CT_R '<w:r>' at 0x10e01d1d8>,
#  <CT_R '<w:r>' at 0x10e01d228>,
#  <CT_R '<w:r>' at 0x10e01d278>,
#  <CT_R '<w:r>' at 0x10e01d2c8>,
#  <CT_R '<w:r>' at 0x10e01d318>,
#  <CT_R '<w:r>' at 0x10e01d368>,
#  <CT_R '<w:r>' at 0x10e01d3b8>,
#  <CT_R '<w:r>' at 0x10e01d408>,
#  <CT_R '<w:r>' at 0x10e01d458>,
#  <CT_R '<w:r>' at 0x10e01d4a8>,
#  <CT_R '<w:r>' at 0x10e01d4f8>,
#  <CT_R '<w:r>' at 0x10e01d548>,
#  <CT_R '<w:r>' at 0x10e01d598>,
#  <CT_R '<w:r>' at 0x10e01d5e8>,
#  <CT_R '<w:r>' at 0x10e01d638>,
#  <CT_R '<w:r>' at 0x10e01d688>,
#  <CT_R '<w:r>' at 0x10e01d6d8>,
#  <CT_R '<w:r>' at 0x10e01d728>,
#  <CT_R '<w:r>' at 0x10e01d778>,
#  <CT_R '<w:r>' at 0x10e01d7c8>,
#  <CT_R '<w:r>' at 0x10e01d818>,
#  <CT_R '<w:r>' at 0x10e01d868>,
#  <CT_R '<w:r>' at 0x10e01d8b8>,
#  <CT_R '<w:r>' at 0x10e01d908>,
#  <CT_R '<w:r>' at 0x10e01d958>,
#  <CT_R '<w:r>' at 0x10e01d9a8>,
#  <CT_R '<w:r>' at 0x10e01d9f8>,
#  <CT_R '<w:r>' at 0x10e01da48>,
#  <CT_R '<w:r>' at 0x10e01da98>,
#  <CT_R '<w:r>' at 0x10e01dae8>,
#  <CT_R '<w:r>' at 0x10e01db38>,
#  <CT_R '<w:r>' at 0x10e01db88>,
#  <CT_R '<w:r>' at 0x10e01dbd8>,
#  <CT_R '<w:r>' at 0x10e01dc28>,
#  <CT_R '<w:r>' at 0x10e01dc78>,
#  <CT_R '<w:r>' at 0x10e01dcc8>,
#  <CT_R '<w:r>' at 0x10e01dd18>,
#  <CT_R '<w:r>' at 0x10e01dd68>,
#  <CT_R '<w:r>' at 0x10e01ddb8>,
#  <CT_R '<w:r>' at 0x10e01de08>,
#  <CT_R '<w:r>' at 0x10e01de58>,
#  <CT_R '<w:r>' at 0x10e01dea8>,
#  <CT_R '<w:r>' at 0x10e01def8>,
#  <CT_R '<w:r>' at 0x10e01df48>,
#  <CT_R '<w:r>' at 0x10e01df98>,
#  <CT_R '<w:r>' at 0x10e026048>,
#  <CT_R '<w:r>' at 0x10e026098>,
#  <CT_R '<w:r>' at 0x10e0260e8>,
#  <CT_R '<w:r>' at 0x10e026138>,
#  <CT_R '<w:r>' at 0x10e026188>,
#  <CT_R '<w:r>' at 0x10e0261d8>,
#  <CT_R '<w:r>' at 0x10e026228>,
#  <CT_R '<w:r>' at 0x10e026278>,
#  <CT_R '<w:r>' at 0x10e0262c8>,
#  <CT_R '<w:r>' at 0x10e026318>,
#  <CT_R '<w:r>' at 0x10e026368>,
#  <CT_R '<w:r>' at 0x10e0263b8>,
#  <CT_R '<w:r>' at 0x10e026408>,
#  <CT_R '<w:r>' at 0x10e026458>,
#  <CT_R '<w:r>' at 0x10e0264a8>,
#  <CT_R '<w:r>' at 0x10e0264f8>,
#  <CT_R '<w:r>' at 0x10e026548>,
#  <CT_R '<w:r>' at 0x10e026598>,
#  <CT_R '<w:r>' at 0x10e0265e8>,
#  <CT_R '<w:r>' at 0x10e026638>,
#  <CT_R '<w:r>' at 0x10e026688>,
#  <CT_R '<w:r>' at 0x10e0266d8>,
#  <CT_R '<w:r>' at 0x10e026728>,
#  <CT_R '<w:r>' at 0x10e026778>,
#  <CT_R '<w:r>' at 0x10e0267c8>,
#  <CT_R '<w:r>' at 0x10e026818>,
#  <CT_R '<w:r>' at 0x10e026868>,
#  <CT_R '<w:r>' at 0x10e0268b8>,
#  <CT_R '<w:r>' at 0x10e026908>,
#  <CT_R '<w:r>' at 0x10e026958>,
#  <CT_R '<w:r>' at 0x10e0269a8>,
#  <CT_R '<w:r>' at 0x10e0269f8>,
#  <CT_R '<w:r>' at 0x10e026a48>,
#  <CT_R '<w:r>' at 0x10e026a98>,
#  <CT_R '<w:r>' at 0x10e026ae8>,
#  <CT_R '<w:r>' at 0x10e026b38>,
#  <CT_R '<w:r>' at 0x10e026b88>,
#  <CT_R '<w:r>' at 0x10e026bd8>,
#  <CT_R '<w:r>' at 0x10e026c28>,
#  <CT_R '<w:r>' at 0x10e026c78>,
#  <CT_R '<w:r>' at 0x10e026cc8>,
#  <CT_R '<w:r>' at 0x10e026d18>,
#  <CT_R '<w:r>' at 0x10e026d68>,
#  <CT_R '<w:r>' at 0x10e026db8>,
#  <CT_R '<w:r>' at 0x10e026e08>,
#  <CT_R '<w:r>' at 0x10e026e58>,
#  <CT_R '<w:r>' at 0x10e026ea8>,
#  <CT_R '<w:r>' at 0x10e026ef8>,
#  <CT_R '<w:r>' at 0x10e026f48>,
#  <CT_R '<w:r>' at 0x10e026f98>,
#  <CT_R '<w:r>' at 0x1161b7048>,
#  <CT_R '<w:r>' at 0x1161b7098>,
#  <CT_R '<w:r>' at 0x1161b70e8>,
#  <CT_R '<w:r>' at 0x1161b7138>,
#  <CT_R '<w:r>' at 0x1161b7188>,
#  <CT_R '<w:r>' at 0x1161b71d8>,
#  <CT_R '<w:r>' at 0x1161b7228>,
#  <CT_R '<w:r>' at 0x1161b7278>,
#  <CT_R '<w:r>' at 0x1161b72c8>,
#  <CT_R '<w:r>' at 0x1161b7318>,
#  <CT_R '<w:r>' at 0x1161b7368>,
#  <CT_R '<w:r>' at 0x1161b73b8>,
#  <CT_R '<w:r>' at 0x1161b7408>,
#  <CT_R '<w:r>' at 0x1161b7458>,
#  <CT_R '<w:r>' at 0x1161b74a8>,
#  <CT_R '<w:r>' at 0x1161b74f8>,
#  <CT_R '<w:r>' at 0x1161b7548>,
#  <CT_R '<w:r>' at 0x1161b7598>,
#  <CT_R '<w:r>' at 0x1161b75e8>,
#  <CT_R '<w:r>' at 0x1161b7638>,
#  <CT_R '<w:r>' at 0x1161b7688>,
#  <CT_R '<w:r>' at 0x1161b76d8>,
#  <CT_R '<w:r>' at 0x1161b7728>,
#  <CT_R '<w:r>' at 0x1161b7778>,
#  <CT_R '<w:r>' at 0x1161b77c8>,
#  <CT_R '<w:r>' at 0x1161b7818>,
#  <CT_R '<w:r>' at 0x1161b7868>,
#  <CT_R '<w:r>' at 0x1161b78b8>,
#  <CT_R '<w:r>' at 0x1161b7908>,
#  <CT_R '<w:r>' at 0x1161b7958>,
#  <CT_R '<w:r>' at 0x1161b79a8>,
#  <CT_R '<w:r>' at 0x1161b79f8>,
#  <CT_R '<w:r>' at 0x1161b7a48>,
#  <CT_R '<w:r>' at 0x1161b7a98>,
#  <CT_R '<w:r>' at 0x1161b7ae8>,
#  <CT_R '<w:r>' at 0x1161b7b38>,
#  <CT_R '<w:r>' at 0x1161b7b88>,
#  <CT_R '<w:r>' at 0x1161b7bd8>,
#  <CT_R '<w:r>' at 0x1161b7c28>,
#  <CT_R '<w:r>' at 0x1161b7c78>,
#  <CT_R '<w:r>' at 0x1161b7cc8>,
#  <CT_R '<w:r>' at 0x1161b7d18>,
#  <CT_R '<w:r>' at 0x1161b7d68>,
#  <CT_R '<w:r>' at 0x1161b7db8>,
#  <CT_R '<w:r>' at 0x1161b7e08>,
#  <CT_R '<w:r>' at 0x1161b7e58>,
#  <CT_R '<w:r>' at 0x1161b7ea8>,
#  <CT_R '<w:r>' at 0x1161b7ef8>,
#  <CT_R '<w:r>' at 0x1161b7f48>,
#  <CT_R '<w:r>' at 0x1161b7f98>,
#  <CT_R '<w:r>' at 0x1161ba048>,
#  <CT_R '<w:r>' at 0x1161ba098>,
#  <CT_R '<w:r>' at 0x1161ba0e8>,
#  <CT_R '<w:r>' at 0x1161ba138>,
#  <CT_R '<w:r>' at 0x1161ba188>,
#  <CT_R '<w:r>' at 0x1161ba1d8>,
#  <CT_R '<w:r>' at 0x1161ba228>,
#  <CT_R '<w:r>' at 0x1161ba278>,
#  <CT_R '<w:r>' at 0x1161ba2c8>,
#  <CT_R '<w:r>' at 0x1161ba318>,
#  <CT_R '<w:r>' at 0x1161ba368>,
#  <CT_R '<w:r>' at 0x1161ba3b8>,
#  <CT_R '<w:r>' at 0x1161ba408>,
#  <CT_R '<w:r>' at 0x1161ba458>,
#  <CT_R '<w:r>' at 0x1161ba4a8>,
#  <CT_R '<w:r>' at 0x1161ba4f8>,
#  <CT_R '<w:r>' at 0x1161ba548>,
#  <CT_R '<w:r>' at 0x1161ba598>,
#  <CT_R '<w:r>' at 0x1161ba5e8>,
#  <CT_R '<w:r>' at 0x1161ba638>,
#  <CT_R '<w:r>' at 0x1161ba688>,
#  <CT_R '<w:r>' at 0x1161ba6d8>,
#  <CT_R '<w:r>' at 0x1161ba728>,
#  <CT_R '<w:r>' at 0x1161ba778>,
#  <CT_R '<w:r>' at 0x1161ba7c8>,
#  <CT_R '<w:r>' at 0x1161ba818>,
#  <CT_R '<w:r>' at 0x1161ba868>,
#  <CT_R '<w:r>' at 0x1161ba8b8>,
#  <CT_R '<w:r>' at 0x1161ba908>,
#  <CT_R '<w:r>' at 0x1161ba958>,
#  <CT_R '<w:r>' at 0x1161ba9a8>,
#  <CT_R '<w:r>' at 0x1161ba9f8>,
#  <CT_R '<w:r>' at 0x1161baa48>,
#  <CT_R '<w:r>' at 0x1161baa98>,
#  <CT_R '<w:r>' at 0x1161baae8>,
#  <CT_R '<w:r>' at 0x1161bab38>,
#  <CT_R '<w:r>' at 0x1161bab88>,
#  <CT_R '<w:r>' at 0x1161babd8>,
#  <CT_R '<w:r>' at 0x1161bac28>,
#  <CT_R '<w:r>' at 0x1161bac78>,
#  <CT_R '<w:r>' at 0x1161bacc8>,
#  <CT_R '<w:r>' at 0x1161bad18>,
#  <CT_R '<w:r>' at 0x1161bad68>,
#  <CT_R '<w:r>' at 0x1161badb8>,
#  <CT_R '<w:r>' at 0x1161bae08>,
#  <CT_R '<w:r>' at 0x1161bae58>,
#  <CT_R '<w:r>' at 0x1161baea8>,
#  <CT_R '<w:r>' at 0x1161baef8>,
#  <CT_R '<w:r>' at 0x1161baf48>,
#  <CT_R '<w:r>' at 0x1161baf98>,
#  <CT_R '<w:r>' at 0x1161bd048>,
#  <CT_R '<w:r>' at 0x1161bd098>,
#  <CT_R '<w:r>' at 0x1161bd0e8>,
#  <CT_R '<w:r>' at 0x1161bd138>,
#  <CT_R '<w:r>' at 0x1161bd188>,
#  <CT_R '<w:r>' at 0x1161bd1d8>,
#  <CT_R '<w:r>' at 0x1161bd228>,
#  <CT_R '<w:r>' at 0x1161bd278>,
#  <CT_R '<w:r>' at 0x1161bd2c8>,
#  <CT_R '<w:r>' at 0x1161bd318>,
#  <CT_R '<w:r>' at 0x1161bd368>,
#  <CT_R '<w:r>' at 0x1161bd3b8>,
#  <CT_R '<w:r>' at 0x1161bd408>,
#  <CT_R '<w:r>' at 0x1161bd458>,
#  <CT_R '<w:r>' at 0x1161bd4a8>,
#  <CT_R '<w:r>' at 0x1161bd4f8>,
#  <CT_R '<w:r>' at 0x1161bd548>,
#  <CT_R '<w:r>' at 0x1161bd598>,
#  <CT_R '<w:r>' at 0x1161bd5e8>,
#  <CT_R '<w:r>' at 0x1161bd638>,
#  <CT_R '<w:r>' at 0x1161bd688>,
#  <CT_R '<w:r>' at 0x1161bd6d8>,
#  <CT_R '<w:r>' at 0x1161bd728>,
#  <CT_R '<w:r>' at 0x1161bd778>,
#  <CT_R '<w:r>' at 0x1161bd7c8>,
#  <CT_R '<w:r>' at 0x1161bd818>,
#  <CT_R '<w:r>' at 0x1161bd868>,
#  <CT_R '<w:r>' at 0x1161bd8b8>,
#  <CT_R '<w:r>' at 0x1161bd908>,
#  <CT_R '<w:r>' at 0x1161bd958>,
#  <CT_R '<w:r>' at 0x1161bd9a8>,
#  <CT_R '<w:r>' at 0x1161bd9f8>,
#  <CT_R '<w:r>' at 0x1161bda48>,
#  <CT_R '<w:r>' at 0x1161bda98>,
#  <CT_R '<w:r>' at 0x1161bdae8>,
#  <CT_R '<w:r>' at 0x1161bdb38>,
#  <CT_R '<w:r>' at 0x1161bdb88>,
#  <CT_R '<w:r>' at 0x1161bdbd8>,
#  <CT_R '<w:r>' at 0x1161bdc28>,
#  <CT_R '<w:r>' at 0x1161bdc78>,
#  <CT_R '<w:r>' at 0x1161bdcc8>,
#  <CT_R '<w:r>' at 0x1161bdd18>,
#  <CT_R '<w:r>' at 0x1161bdd68>,
#  <CT_R '<w:r>' at 0x1161bddb8>,
#  <CT_R '<w:r>' at 0x1161bde08>,
#  <CT_R '<w:r>' at 0x1161bde58>,
#  <CT_R '<w:r>' at 0x1161bdea8>,
#  <CT_R '<w:r>' at 0x1161bdef8>,
#  <CT_R '<w:r>' at 0x1161bdf48>,
#  <CT_R '<w:r>' at 0x1161bdf98>,
#  <CT_R '<w:r>' at 0x1161c5048>,
#  <CT_R '<w:r>' at 0x1161c5098>,
#  <CT_R '<w:r>' at 0x1161c50e8>,
#  <CT_R '<w:r>' at 0x1161c5138>,
#  <CT_R '<w:r>' at 0x1161c5188>,
#  <CT_R '<w:r>' at 0x1161c51d8>,
#  <CT_R '<w:r>' at 0x1161c5228>,
#  <CT_R '<w:r>' at 0x1161c5278>,
#  <CT_R '<w:r>' at 0x1161c52c8>,
#  <CT_R '<w:r>' at 0x1161c5318>,
#  <CT_R '<w:r>' at 0x1161c5368>,
#  <CT_R '<w:r>' at 0x1161c53b8>,
#  <CT_R '<w:r>' at 0x1161c5408>,
#  <CT_R '<w:r>' at 0x1161c5458>,
#  <CT_R '<w:r>' at 0x1161c54a8>,
#  <CT_R '<w:r>' at 0x1161c54f8>,
#  <CT_R '<w:r>' at 0x1161c5548>,
#  <CT_R '<w:r>' at 0x1161c5598>,
#  <CT_R '<w:r>' at 0x1161c55e8>,
#  <CT_R '<w:r>' at 0x1161c5638>,
#  <CT_R '<w:r>' at 0x1161c5688>,
#  <CT_R '<w:r>' at 0x1161c56d8>,
#  <CT_R '<w:r>' at 0x1161c5728>,
#  <CT_R '<w:r>' at 0x1161c5778>,
#  <CT_R '<w:r>' at 0x1161c57c8>,
#  <CT_R '<w:r>' at 0x1161c5818>,
#  <CT_R '<w:r>' at 0x1161c5868>,
#  <CT_R '<w:r>' at 0x1161c58b8>,
#  <CT_R '<w:r>' at 0x1161c5908>,
#  <CT_R '<w:r>' at 0x1161c5958>,
#  <CT_R '<w:r>' at 0x1161c59a8>,
#  <CT_R '<w:r>' at 0x1161c59f8>,
#  <CT_R '<w:r>' at 0x1161c5a48>,
#  <CT_R '<w:r>' at 0x1161c5a98>,
#  <CT_R '<w:r>' at 0x1161c5ae8>,
#  <CT_R '<w:r>' at 0x1161c5b38>,
#  <CT_R '<w:r>' at 0x1161c5b88>,
#  <CT_R '<w:r>' at 0x1161c5bd8>,
#  <CT_R '<w:r>' at 0x1161c5c28>,
#  <CT_R '<w:r>' at 0x1161c5c78>,
#  <CT_R '<w:r>' at 0x1161c5cc8>,
#  <CT_R '<w:r>' at 0x1161c5d18>,
#  <CT_R '<w:r>' at 0x1161c5d68>,
#  <CT_R '<w:r>' at 0x1161c5db8>,
#  <CT_R '<w:r>' at 0x1161c5e08>,
#  <CT_R '<w:r>' at 0x1161c5e58>,
#  <CT_R '<w:r>' at 0x1161c5ea8>,
#  <CT_R '<w:r>' at 0x1161c5ef8>,
#  <CT_R '<w:r>' at 0x1161c5f48>,
#  <CT_R '<w:r>' at 0x1161c5f98>,
#  <CT_R '<w:r>' at 0x1161c6048>,
#  <CT_R '<w:r>' at 0x1161c6098>,
#  <CT_R '<w:r>' at 0x1161c60e8>,
#  <CT_R '<w:r>' at 0x1161c6138>,
#  <CT_R '<w:r>' at 0x1161c6188>,
#  <CT_R '<w:r>' at 0x1161c61d8>,
#  <CT_R '<w:r>' at 0x1161c6228>,
#  <CT_R '<w:r>' at 0x1161c6278>,
#  <CT_R '<w:r>' at 0x1161c62c8>,
#  <CT_R '<w:r>' at 0x1161c6318>,
#  <CT_R '<w:r>' at 0x1161c6368>,
#  <CT_R '<w:r>' at 0x1161c63b8>,
#  <CT_R '<w:r>' at 0x1161c6408>,
#  <CT_R '<w:r>' at 0x1161c6458>,
#  <CT_R '<w:r>' at 0x1161c64a8>,
#  <CT_R '<w:r>' at 0x1161c64f8>,
#  <CT_R '<w:r>' at 0x1161c6548>,
#  <CT_R '<w:r>' at 0x1161c6598>,
#  <CT_R '<w:r>' at 0x1161c65e8>,
#  <CT_R '<w:r>' at 0x1161c6638>,
#  <CT_R '<w:r>' at 0x1161c6688>,
#  <CT_R '<w:r>' at 0x1161c66d8>,
#  <CT_R '<w:r>' at 0x1161c6728>,
#  <CT_R '<w:r>' at 0x1161c6778>,
#  <CT_R '<w:r>' at 0x1161c67c8>,
#  <CT_R '<w:r>' at 0x1161c6818>,
#  <CT_R '<w:r>' at 0x1161c6868>,
#  <CT_R '<w:r>' at 0x1161c68b8>,
#  <CT_R '<w:r>' at 0x1161c6908>,
#  <CT_R '<w:r>' at 0x1161c6958>,
#  <CT_R '<w:r>' at 0x1161c69a8>,
#  <CT_R '<w:r>' at 0x1161c69f8>,
#  <CT_R '<w:r>' at 0x1161c6a48>,
#  <CT_R '<w:r>' at 0x1161c6a98>,
#  <CT_R '<w:r>' at 0x1161c6ae8>,
#  <CT_R '<w:r>' at 0x1161c6b38>,
#  <CT_R '<w:r>' at 0x1161c6b88>,
#  <CT_R '<w:r>' at 0x1161c6bd8>,
#  <CT_R '<w:r>' at 0x1161c6c28>,
#  <CT_R '<w:r>' at 0x1161c6c78>,
#  <CT_R '<w:r>' at 0x1161c6cc8>,
#  <CT_R '<w:r>' at 0x1161c6d18>,
#  <CT_R '<w:r>' at 0x1161c6d68>,
#  <CT_R '<w:r>' at 0x1161c6db8>,
#  <CT_R '<w:r>' at 0x1161c6e08>,
#  <CT_R '<w:r>' at 0x1161c6e58>,
#  <CT_R '<w:r>' at 0x1161c6ea8>,
#  <CT_R '<w:r>' at 0x1161c6ef8>,
#  <CT_R '<w:r>' at 0x1161c6f48>,
#  <CT_R '<w:r>' at 0x1161c6f98>,
#  <CT_R '<w:r>' at 0x1161c7048>,
#  <CT_R '<w:r>' at 0x1161c7098>,
#  <CT_R '<w:r>' at 0x1161c70e8>,
#  <CT_R '<w:r>' at 0x1161c7138>,
#  <CT_R '<w:r>' at 0x1161c7188>,
#  <CT_R '<w:r>' at 0x1161c71d8>,
#  <CT_R '<w:r>' at 0x1161c7228>,
#  <CT_R '<w:r>' at 0x1161c7278>,
#  <CT_R '<w:r>' at 0x1161c72c8>,
#  <CT_R '<w:r>' at 0x1161c7318>,
#  <CT_R '<w:r>' at 0x1161c7368>,
#  <CT_R '<w:r>' at 0x1161c73b8>,
#  <CT_R '<w:r>' at 0x1161c7408>,
#  <CT_R '<w:r>' at 0x1161c7458>,
#  <CT_R '<w:r>' at 0x1161c74a8>,
#  <CT_R '<w:r>' at 0x1161c74f8>,
#  <CT_R '<w:r>' at 0x1161c7548>,
#  <CT_R '<w:r>' at 0x1161c7598>,
#  <CT_R '<w:r>' at 0x1161c75e8>,
#  <CT_R '<w:r>' at 0x1161c7638>,
#  <CT_R '<w:r>' at 0x1161c7688>,
#  <CT_R '<w:r>' at 0x1161c76d8>,
#  <CT_R '<w:r>' at 0x1161c7728>,
#  <CT_R '<w:r>' at 0x1161c7778>,
#  <CT_R '<w:r>' at 0x1161c77c8>,
#  <CT_R '<w:r>' at 0x1161c7818>,
#  <CT_R '<w:r>' at 0x1161c7868>,
#  <CT_R '<w:r>' at 0x1161c78b8>,
#  <CT_R '<w:r>' at 0x1161c7908>,
#  <CT_R '<w:r>' at 0x1161c7958>,
#  <CT_R '<w:r>' at 0x1161c79a8>,
#  <CT_R '<w:r>' at 0x1161c79f8>,
#  <CT_R '<w:r>' at 0x1161c7a48>,
#  <CT_R '<w:r>' at 0x1161c7a98>,
#  <CT_R '<w:r>' at 0x1161c7ae8>,
#  <CT_R '<w:r>' at 0x1161c7b38>,
#  <CT_R '<w:r>' at 0x1161c7b88>,
#  <CT_R '<w:r>' at 0x1161c7bd8>,
#  <CT_R '<w:r>' at 0x1161c7c28>,
#  <CT_R '<w:r>' at 0x1161c7c78>,
#  <CT_R '<w:r>' at 0x1161c7cc8>,
#  <CT_R '<w:r>' at 0x1161c7d18>,
#  <CT_R '<w:r>' at 0x1161c7d68>,
#  <CT_R '<w:r>' at 0x1161c7db8>,
#  <CT_R '<w:r>' at 0x1161c7e08>,
#  <CT_R '<w:r>' at 0x1161c7e58>,
#  <CT_R '<w:r>' at 0x1161c7ea8>,
#  <CT_R '<w:r>' at 0x1161c7ef8>,
#  <CT_R '<w:r>' at 0x1161c7f48>,
#  <CT_R '<w:r>' at 0x1161c7f98>,
#  <CT_R '<w:r>' at 0x1161c8048>,
#  <CT_R '<w:r>' at 0x1161c8098>,
#  <CT_R '<w:r>' at 0x1161c80e8>,
#  <CT_R '<w:r>' at 0x1161c8138>,
#  <CT_R '<w:r>' at 0x1161c8188>,
#  <CT_R '<w:r>' at 0x1161c81d8>,
#  <CT_R '<w:r>' at 0x1161c8228>,
#  <CT_R '<w:r>' at 0x1161c8278>,
#  <CT_R '<w:r>' at 0x1161c82c8>,
#  <CT_R '<w:r>' at 0x1161c8318>,
#  <CT_R '<w:r>' at 0x1161c8368>,
#  <CT_R '<w:r>' at 0x1161c83b8>,
#  <CT_R '<w:r>' at 0x1161c8408>,
#  <CT_R '<w:r>' at 0x1161c8458>,
#  <CT_R '<w:r>' at 0x1161c84a8>,
#  <CT_R '<w:r>' at 0x1161c84f8>,
#  <CT_R '<w:r>' at 0x1161c8548>,
#  <CT_R '<w:r>' at 0x1161c8598>,
#  <CT_R '<w:r>' at 0x1161c85e8>,
#  <CT_R '<w:r>' at 0x1161c8638>,
#  <CT_R '<w:r>' at 0x1161c8688>,
#  <CT_R '<w:r>' at 0x1161c86d8>,
#  <CT_R '<w:r>' at 0x1161c8728>,
#  <CT_R '<w:r>' at 0x1161c8778>,
#  <CT_R '<w:r>' at 0x1161c87c8>,
#  <CT_R '<w:r>' at 0x1161c8818>,
#  <CT_R '<w:r>' at 0x1161c8868>,
#  <CT_R '<w:r>' at 0x1161c88b8>,
#  <CT_R '<w:r>' at 0x1161c8908>,
#  <CT_R '<w:r>' at 0x1161c8958>,
#  <CT_R '<w:r>' at 0x1161c89a8>,
#  <CT_R '<w:r>' at 0x1161c89f8>,
#  <CT_R '<w:r>' at 0x1161c8a48>,
#  <CT_R '<w:r>' at 0x1161c8a98>,
#  <CT_R '<w:r>' at 0x1161c8ae8>,
#  <CT_R '<w:r>' at 0x1161c8b38>,
#  <CT_R '<w:r>' at 0x1161c8b88>,
#  <CT_R '<w:r>' at 0x1161c8bd8>,
#  <CT_R '<w:r>' at 0x1161c8c28>,
#  <CT_R '<w:r>' at 0x1161c8c78>,
#  <CT_R '<w:r>' at 0x1161c8cc8>,
#  <CT_R '<w:r>' at 0x1161c8d18>,
#  <CT_R '<w:r>' at 0x1161c8d68>,
#  <CT_R '<w:r>' at 0x1161c8db8>,
#  <CT_R '<w:r>' at 0x1161c8e08>,
#  <CT_R '<w:r>' at 0x1161c8e58>,
#  <CT_R '<w:r>' at 0x1161c8ea8>,
#  <CT_R '<w:r>' at 0x1161c8ef8>,
#  <CT_R '<w:r>' at 0x1161c8f48>,
#  <CT_R '<w:r>' at 0x1161c8f98>,
#  <CT_R '<w:r>' at 0x1161c9048>,
#  <CT_R '<w:r>' at 0x1161c9098>,
#  <CT_R '<w:r>' at 0x1161c90e8>,
#  <CT_R '<w:r>' at 0x1161c9138>,
#  <CT_R '<w:r>' at 0x1161c9188>,
#  <CT_R '<w:r>' at 0x1161c91d8>,
#  <CT_R '<w:r>' at 0x1161c9228>,
#  <CT_R '<w:r>' at 0x1161c9278>,
#  <CT_R '<w:r>' at 0x1161c92c8>,
#  <CT_R '<w:r>' at 0x1161c9318>,
#  <CT_R '<w:r>' at 0x1161c9368>,
#  <CT_R '<w:r>' at 0x1161c93b8>,
#  <CT_R '<w:r>' at 0x1161c9408>,
#  <CT_R '<w:r>' at 0x1161c9458>,
#  <CT_R '<w:r>' at 0x1161c94a8>,
#  <CT_R '<w:r>' at 0x1161c94f8>,
#  <CT_R '<w:r>' at 0x1161c9548>,
#  <CT_R '<w:r>' at 0x1161c9598>,
#  <CT_R '<w:r>' at 0x1161c95e8>,
#  <CT_R '<w:r>' at 0x1161c9638>,
#  <CT_R '<w:r>' at 0x1161c9688>,
#  <CT_R '<w:r>' at 0x1161c96d8>,
#  <CT_R '<w:r>' at 0x1161c9728>,
#  <CT_R '<w:r>' at 0x1161c9778>,
#  <CT_R '<w:r>' at 0x1161c97c8>,
#  <CT_R '<w:r>' at 0x1161c9818>,
#  <CT_R '<w:r>' at 0x1161c9868>,
#  <CT_R '<w:r>' at 0x1161c98b8>,
#  <CT_R '<w:r>' at 0x1161c9908>,
#  <CT_R '<w:r>' at 0x1161c9958>,
#  <CT_R '<w:r>' at 0x1161c99a8>,
#  <CT_R '<w:r>' at 0x1161c99f8>,
#  <CT_R '<w:r>' at 0x1161c9a48>,
#  <CT_R '<w:r>' at 0x1161c9a98>,
#  <CT_R '<w:r>' at 0x1161c9ae8>,
#  <CT_R '<w:r>' at 0x1161c9b38>,
#  <CT_R '<w:r>' at 0x1161c9b88>,
#  <CT_R '<w:r>' at 0x1161c9bd8>,
#  <CT_R '<w:r>' at 0x1161c9c28>,
#  <CT_R '<w:r>' at 0x1161c9c78>,
#  <CT_R '<w:r>' at 0x1161c9cc8>,
#  <CT_R '<w:r>' at 0x1161c9d18>,
#  <CT_R '<w:r>' at 0x1161c9d68>,
#  <CT_R '<w:r>' at 0x1161c9db8>,
#  <CT_R '<w:r>' at 0x1161c9e08>,
#  <CT_R '<w:r>' at 0x1161c9e58>,
#  <CT_R '<w:r>' at 0x1161c9ea8>,
#  <CT_R '<w:r>' at 0x1161c9ef8>,
#  <CT_R '<w:r>' at 0x1161c9f48>,
#  <CT_R '<w:r>' at 0x1161c9f98>,
#  <CT_R '<w:r>' at 0x1161ca048>,
#  <CT_R '<w:r>' at 0x1161ca098>,
#  <CT_R '<w:r>' at 0x1161ca0e8>,
#  <CT_R '<w:r>' at 0x1161ca138>,
#  <CT_R '<w:r>' at 0x1161ca188>,
#  <CT_R '<w:r>' at 0x1161ca1d8>,
#  <CT_R '<w:r>' at 0x1161ca228>,
#  <CT_R '<w:r>' at 0x1161ca278>,
#  <CT_R '<w:r>' at 0x1161ca2c8>,
#  <CT_R '<w:r>' at 0x1161ca318>,
#  <CT_R '<w:r>' at 0x1161ca368>,
#  <CT_R '<w:r>' at 0x1161ca3b8>,
#  <CT_R '<w:r>' at 0x1161ca408>,
#  <CT_R '<w:r>' at 0x1161ca458>,
#  <CT_R '<w:r>' at 0x1161ca4a8>,
#  <CT_R '<w:r>' at 0x1161ca4f8>,
#  <CT_R '<w:r>' at 0x1161ca548>,
#  <CT_R '<w:r>' at 0x1161ca598>,
#  <CT_R '<w:r>' at 0x1161ca5e8>,
#  <CT_R '<w:r>' at 0x1161ca638>,
#  <CT_R '<w:r>' at 0x1161ca688>,
#  <CT_R '<w:r>' at 0x1161ca6d8>,
#  <CT_R '<w:r>' at 0x1161ca728>,
#  <CT_R '<w:r>' at 0x1161ca778>,
#  <CT_R '<w:r>' at 0x1161ca7c8>,
#  <CT_R '<w:r>' at 0x1161ca818>,
#  <CT_R '<w:r>' at 0x1161ca868>,
#  <CT_R '<w:r>' at 0x1161ca8b8>,
#  <CT_R '<w:r>' at 0x1161ca908>,
#  <CT_R '<w:r>' at 0x1161ca958>,
#  <CT_R '<w:r>' at 0x1161ca9a8>,
#  <CT_R '<w:r>' at 0x1161ca9f8>,
#  <CT_R '<w:r>' at 0x1161caa48>,
#  <CT_R '<w:r>' at 0x1161caa98>,
#  <CT_R '<w:r>' at 0x1161caae8>,
#  <CT_R '<w:r>' at 0x1161cab38>,
#  <CT_R '<w:r>' at 0x1161cab88>,
#  <CT_R '<w:r>' at 0x1161cabd8>,
#  <CT_R '<w:r>' at 0x1161cac28>,
#  <CT_R '<w:r>' at 0x1161cac78>,
#  <CT_R '<w:r>' at 0x1161cacc8>,
#  <CT_R '<w:r>' at 0x1161cad18>,
#  <CT_R '<w:r>' at 0x1161cad68>,
#  <CT_R '<w:r>' at 0x1161cadb8>,
#  <CT_R '<w:r>' at 0x1161cae08>,
#  <CT_R '<w:r>' at 0x1161cae58>,
#  <CT_R '<w:r>' at 0x1161caea8>,
#  <CT_R '<w:r>' at 0x1161caef8>,
#  <CT_R '<w:r>' at 0x1161caf48>,
#  <CT_R '<w:r>' at 0x1161caf98>,
#  <CT_R '<w:r>' at 0x10dd19688>,
#  <CT_R '<w:r>' at 0x10dd196d8>,
#  <CT_R '<w:r>' at 0x10dd19728>,
#  <CT_R '<w:r>' at 0x10dd19778>,
#  <CT_R '<w:r>' at 0x10dd197c8>,
#  <CT_R '<w:r>' at 0x10dd19818>,
#  <CT_R '<w:r>' at 0x10dd19868>,
#  <CT_R '<w:r>' at 0x10dd198b8>,
#  <CT_R '<w:r>' at 0x10dd19908>,
#  <CT_R '<w:r>' at 0x10dd19958>,
#  <CT_R '<w:r>' at 0x10dd199a8>,
#  <CT_R '<w:r>' at 0x10dd199f8>,
#  <CT_R '<w:r>' at 0x10dd19a48>,
#  <CT_R '<w:r>' at 0x10dd19a98>,
#  <CT_R '<w:r>' at 0x10dd19ae8>,
#  <CT_R '<w:r>' at 0x10dd19b38>,
#  <CT_R '<w:r>' at 0x10dd19b88>,
#  <CT_R '<w:r>' at 0x10dd19bd8>,
#  <CT_R '<w:r>' at 0x10dd19c28>,
#  <CT_R '<w:r>' at 0x10dd19c78>,
#  <CT_R '<w:r>' at 0x10dd19cc8>,
#  <CT_R '<w:r>' at 0x10dd19d18>,
#  <CT_R '<w:r>' at 0x10dd19d68>,
#  <CT_R '<w:r>' at 0x10dd19db8>,
#  <CT_R '<w:r>' at 0x10dd19e08>,
#  <CT_R '<w:r>' at 0x10dd19e58>,
#  <CT_R '<w:r>' at 0x10dd19ea8>,
#  <CT_R '<w:r>' at 0x10dd19ef8>,
#  <CT_R '<w:r>' at 0x10dd19f48>,
#  <CT_R '<w:r>' at 0x10dd19f98>,
#  <CT_R '<w:r>' at 0x10dd19638>,
#  <CT_R '<w:r>' at 0x10dd19048>,
#  <CT_R '<w:r>' at 0x10dd19098>,
#  <CT_R '<w:r>' at 0x10dd190e8>,
#  <CT_R '<w:r>' at 0x10dd19138>,
#  <CT_R '<w:r>' at 0x10dd19188>,
#  <CT_R '<w:r>' at 0x10dd191d8>,
#  <CT_R '<w:r>' at 0x10dd19228>,
#  <CT_R '<w:r>' at 0x10dd19278>,
#  <CT_R '<w:r>' at 0x10dd192c8>,
#  <CT_R '<w:r>' at 0x10dd19318>,
#  <CT_R '<w:r>' at 0x10dd19368>,
#  <CT_R '<w:r>' at 0x10dd193b8>,
#  <CT_R '<w:r>' at 0x10dd19408>,
#  <CT_R '<w:r>' at 0x10dd19458>,
#  <CT_R '<w:r>' at 0x10dd194a8>,
#  <CT_R '<w:r>' at 0x10dd194f8>,
#  <CT_R '<w:r>' at 0x10dd19548>,
#  <CT_R '<w:r>' at 0x10dd19598>,
#  <CT_R '<w:r>' at 0x10dd195e8>,
#  <CT_R '<w:r>' at 0x10dd1d048>,
#  <CT_R '<w:r>' at 0x10dd1d098>,
#  <CT_R '<w:r>' at 0x10dd1d0e8>,
#  <CT_R '<w:r>' at 0x10dd1d138>,
#  <CT_R '<w:r>' at 0x10dd1d188>,
#  <CT_R '<w:r>' at 0x10dd1d1d8>,
#  <CT_R '<w:r>' at 0x10dd1d228>,
#  <CT_R '<w:r>' at 0x10dd1d278>,
#  <CT_R '<w:r>' at 0x10dd1d2c8>,
#  <CT_R '<w:r>' at 0x10dd1d318>,
#  <CT_R '<w:r>' at 0x10dd1d368>,
#  <CT_R '<w:r>' at 0x10dd1d3b8>,
#  <CT_R '<w:r>' at 0x10dd1d408>,
#  <CT_R '<w:r>' at 0x10dd1d458>,
#  <CT_R '<w:r>' at 0x10dd1d4a8>,
#  <CT_R '<w:r>' at 0x10dd1d4f8>,
#  <CT_R '<w:r>' at 0x10dd1d548>,
#  <CT_R '<w:r>' at 0x10dd1d598>,
#  <CT_R '<w:r>' at 0x10dd1d5e8>,
#  <CT_R '<w:r>' at 0x10dd1d638>,
#  <CT_R '<w:r>' at 0x10dd1d688>,
#  <CT_R '<w:r>' at 0x10dd1d6d8>,
#  <CT_R '<w:r>' at 0x10dd1d728>,
#  <CT_R '<w:r>' at 0x10dd1d778>,
#  <CT_R '<w:r>' at 0x10dd1d7c8>,
#  <CT_R '<w:r>' at 0x10dd1d818>,
#  <CT_R '<w:r>' at 0x10dd1d868>,
#  <CT_R '<w:r>' at 0x10dd1d8b8>,
#  <CT_R '<w:r>' at 0x10dd1d908>,
#  <CT_R '<w:r>' at 0x10dd1d958>,
#  <CT_R '<w:r>' at 0x10dd1d9a8>,
#  <CT_R '<w:r>' at 0x10dd1d9f8>,
#  <CT_R '<w:r>' at 0x10dd1da48>,
#  <CT_R '<w:r>' at 0x10dd1da98>,
#  <CT_R '<w:r>' at 0x10dd1dae8>,
#  <CT_R '<w:r>' at 0x10dd1db38>,
#  <CT_R '<w:r>' at 0x10dd1db88>,
#  <CT_R '<w:r>' at 0x10dd1dbd8>,
#  <CT_R '<w:r>' at 0x10dd1dc28>,
#  <CT_R '<w:r>' at 0x10dd1dc78>,
#  <CT_R '<w:r>' at 0x10dd1dcc8>,
#  <CT_R '<w:r>' at 0x10dd1dd18>,
#  <CT_R '<w:r>' at 0x10dd1dd68>,
#  <CT_R '<w:r>' at 0x10dd1ddb8>,
#  <CT_R '<w:r>' at 0x10dd1de08>,
#  <CT_R '<w:r>' at 0x10dd1de58>,
#  <CT_R '<w:r>' at 0x10dd1dea8>,
#  <CT_R '<w:r>' at 0x10dd1def8>,
#  <CT_R '<w:r>' at 0x10dd1df48>,
#  <CT_R '<w:r>' at 0x10dd1df98>,
#  <CT_R '<w:r>' at 0x10dd23048>,
#  <CT_R '<w:r>' at 0x10dd23098>,
#  <CT_R '<w:r>' at 0x10dd230e8>,
#  <CT_R '<w:r>' at 0x10dd23138>,
#  <CT_R '<w:r>' at 0x10dd23188>,
#  <CT_R '<w:r>' at 0x10dd231d8>,
#  <CT_R '<w:r>' at 0x10dd23228>,
#  <CT_R '<w:r>' at 0x10dd23278>,
#  <CT_R '<w:r>' at 0x10dd232c8>,
#  <CT_R '<w:r>' at 0x10dd23318>,
#  <CT_R '<w:r>' at 0x10dd23368>,
#  <CT_R '<w:r>' at 0x10dd233b8>,
#  <CT_R '<w:r>' at 0x10dd23408>,
#  <CT_R '<w:r>' at 0x10dd23458>,
#  <CT_R '<w:r>' at 0x10dd234a8>,
#  <CT_R '<w:r>' at 0x10dd234f8>,
#  <CT_R '<w:r>' at 0x10dd23548>,
#  <CT_R '<w:r>' at 0x10dd23598>,
#  <CT_R '<w:r>' at 0x10dd235e8>,
#  <CT_R '<w:r>' at 0x10dd23638>,
#  <CT_R '<w:r>' at 0x10dd23688>,
#  <CT_R '<w:r>' at 0x10dd236d8>,
#  <CT_R '<w:r>' at 0x10dd23728>,
#  <CT_R '<w:r>' at 0x10dd23778>,
#  <CT_R '<w:r>' at 0x10dd237c8>,
#  <CT_R '<w:r>' at 0x10dd23818>,
#  <CT_R '<w:r>' at 0x10dd23868>,
#  <CT_R '<w:r>' at 0x10dd238b8>,
#  <CT_R '<w:r>' at 0x10dd23908>,
#  <CT_R '<w:r>' at 0x10dd23958>,
#  <CT_R '<w:r>' at 0x10dd239a8>,
#  <CT_R '<w:r>' at 0x10dd239f8>,
#  <CT_R '<w:r>' at 0x10dd23a48>,
#  <CT_R '<w:r>' at 0x10dd23a98>,
#  <CT_R '<w:r>' at 0x10dd23ae8>,
#  <CT_R '<w:r>' at 0x10dd23b38>,
#  <CT_R '<w:r>' at 0x10dd23b88>,
#  <CT_R '<w:r>' at 0x10dd23bd8>,
#  <CT_R '<w:r>' at 0x10dd23c28>,
#  <CT_R '<w:r>' at 0x10dd23c78>,
#  <CT_R '<w:r>' at 0x10dd23cc8>,
#  <CT_R '<w:r>' at 0x10dd23d18>,
#  <CT_R '<w:r>' at 0x10dd23d68>,
#  <CT_R '<w:r>' at 0x10dd23db8>,
#  <CT_R '<w:r>' at 0x10dd23e08>,
#  <CT_R '<w:r>' at 0x10dd23e58>,
#  <CT_R '<w:r>' at 0x10dd23ea8>,
#  <CT_R '<w:r>' at 0x10dd23ef8>,
#  <CT_R '<w:r>' at 0x10dd23f48>,
#  <CT_R '<w:r>' at 0x10dd23f98>,
#  <CT_R '<w:r>' at 0x10dd24048>,
#  <CT_R '<w:r>' at 0x10dd24098>,
#  <CT_R '<w:r>' at 0x10dd240e8>,
#  <CT_R '<w:r>' at 0x10dd24138>,
#  <CT_R '<w:r>' at 0x10dd24188>,
#  <CT_R '<w:r>' at 0x10dd241d8>,
#  <CT_R '<w:r>' at 0x10dd24228>,
#  <CT_R '<w:r>' at 0x10dd24278>,
#  <CT_R '<w:r>' at 0x10dd242c8>,
#  <CT_R '<w:r>' at 0x10dd24318>,
#  <CT_R '<w:r>' at 0x10dd24368>,
#  <CT_R '<w:r>' at 0x10dd243b8>,
#  <CT_R '<w:r>' at 0x10dd24408>,
#  <CT_R '<w:r>' at 0x10dd24458>,
#  <CT_R '<w:r>' at 0x10dd244a8>,
#  <CT_R '<w:r>' at 0x10dd244f8>,
#  <CT_R '<w:r>' at 0x10dd24548>,
#  <CT_R '<w:r>' at 0x10dd24598>,
#  <CT_R '<w:r>' at 0x10dd245e8>,
#  <CT_R '<w:r>' at 0x10dd24638>,
#  <CT_R '<w:r>' at 0x10dd24688>,
#  <CT_R '<w:r>' at 0x10dd246d8>,
#  <CT_R '<w:r>' at 0x10dd24728>,
#  <CT_R '<w:r>' at 0x10dd24778>,
#  <CT_R '<w:r>' at 0x10dd247c8>,
#  <CT_R '<w:r>' at 0x10dd24818>,
#  <CT_R '<w:r>' at 0x10dd24868>,
#  <CT_R '<w:r>' at 0x10dd248b8>,
#  <CT_R '<w:r>' at 0x10dd24908>,
#  <CT_R '<w:r>' at 0x10dd24958>,
#  <CT_R '<w:r>' at 0x10dd249a8>,
#  <CT_R '<w:r>' at 0x10dd249f8>,
#  <CT_R '<w:r>' at 0x10dd24a48>,
#  <CT_R '<w:r>' at 0x10dd24a98>,
#  <CT_R '<w:r>' at 0x10dd24ae8>,
#  <CT_R '<w:r>' at 0x10dd24b38>,
#  <CT_R '<w:r>' at 0x10dd24b88>,
#  <CT_R '<w:r>' at 0x10dd24bd8>,
#  <CT_R '<w:r>' at 0x10dd24c28>,
#  <CT_R '<w:r>' at 0x10dd24c78>,
#  <CT_R '<w:r>' at 0x10dd24cc8>,
#  <CT_R '<w:r>' at 0x10dd24d18>,
#  <CT_R '<w:r>' at 0x10dd24d68>,
#  <CT_R '<w:r>' at 0x10dd24db8>,
#  <CT_R '<w:r>' at 0x10dd24e08>,
#  <CT_R '<w:r>' at 0x10dd24e58>,
#  <CT_R '<w:r>' at 0x10dd24ea8>,
#  <CT_R '<w:r>' at 0x10dd24ef8>,
#  <CT_R '<w:r>' at 0x10dd24f48>,
#  <CT_R '<w:r>' at 0x10dd24f98>,
#  <CT_R '<w:r>' at 0x10dd2a048>,
#  <CT_R '<w:r>' at 0x10dd2a098>,
#  <CT_R '<w:r>' at 0x10dd2a0e8>,
#  <CT_R '<w:r>' at 0x10dd2a138>,
#  <CT_R '<w:r>' at 0x10dd2a188>,
#  <CT_R '<w:r>' at 0x10dd2a1d8>,
#  <CT_R '<w:r>' at 0x10dd2a228>,
#  <CT_R '<w:r>' at 0x10dd2a278>,
#  <CT_R '<w:r>' at 0x10dd2a2c8>,
#  <CT_R '<w:r>' at 0x10dd2a318>,
#  <CT_R '<w:r>' at 0x10dd2a368>,
#  <CT_R '<w:r>' at 0x10dd2a3b8>,
#  <CT_R '<w:r>' at 0x10dd2a408>,
#  <CT_R '<w:r>' at 0x10dd2a458>,
#  <CT_R '<w:r>' at 0x10dd2a4a8>,
#  <CT_R '<w:r>' at 0x10dd2a4f8>,
#  <CT_R '<w:r>' at 0x10dd2a548>,
#  <CT_R '<w:r>' at 0x10dd2a598>,
#  <CT_R '<w:r>' at 0x10dd2a5e8>,
#  <CT_R '<w:r>' at 0x10dd2a638>,
#  <CT_R '<w:r>' at 0x10dd2a688>,
#  <CT_R '<w:r>' at 0x10dd2a6d8>,
#  <CT_R '<w:r>' at 0x10dd2a728>,
#  <CT_R '<w:r>' at 0x10dd2a778>,
#  <CT_R '<w:r>' at 0x10dd2a7c8>,
#  <CT_R '<w:r>' at 0x10dd2a818>,
#  <CT_R '<w:r>' at 0x10dd2a868>,
#  <CT_R '<w:r>' at 0x10dd2a8b8>,
#  <CT_R '<w:r>' at 0x10dd2a908>,
#  <CT_R '<w:r>' at 0x10dd2a958>,
#  <CT_R '<w:r>' at 0x10dd2a9a8>,
#  <CT_R '<w:r>' at 0x10dd2a9f8>,
#  <CT_R '<w:r>' at 0x10dd2aa48>,
#  <CT_R '<w:r>' at 0x10dd2aa98>,
#  <CT_R '<w:r>' at 0x10dd2aae8>,
#  <CT_R '<w:r>' at 0x10dd2ab38>,
#  <CT_R '<w:r>' at 0x10dd2ab88>,
#  <CT_R '<w:r>' at 0x10dd2abd8>,
#  <CT_R '<w:r>' at 0x10dd2ac28>,
#  <CT_R '<w:r>' at 0x10dd2ac78>,
#  <CT_R '<w:r>' at 0x10dd2acc8>,
#  <CT_R '<w:r>' at 0x10dd2ad18>,
#  <CT_R '<w:r>' at 0x10dd2ad68>,
#  <CT_R '<w:r>' at 0x10dd2adb8>,
#  <CT_R '<w:r>' at 0x10dd2ae08>,
#  <CT_R '<w:r>' at 0x10dd2ae58>,
#  <CT_R '<w:r>' at 0x10dd2aea8>,
#  <CT_R '<w:r>' at 0x10dd2aef8>,
#  <CT_R '<w:r>' at 0x10dd2af48>,
#  <CT_R '<w:r>' at 0x10dd2af98>,
#  <CT_R '<w:r>' at 0x10dd33048>,
#  <CT_R '<w:r>' at 0x10dd33098>,
#  <CT_R '<w:r>' at 0x10dd330e8>,
#  <CT_R '<w:r>' at 0x10dd33138>,
#  <CT_R '<w:r>' at 0x10dd33188>,
#  <CT_R '<w:r>' at 0x10dd331d8>,
#  <CT_R '<w:r>' at 0x10dd33228>,
#  <CT_R '<w:r>' at 0x10dd33278>,
#  <CT_R '<w:r>' at 0x10dd332c8>,
#  <CT_R '<w:r>' at 0x10dd33318>,
#  <CT_R '<w:r>' at 0x10dd33368>,
#  <CT_R '<w:r>' at 0x10dd333b8>,
#  <CT_R '<w:r>' at 0x10dd33408>,
#  <CT_R '<w:r>' at 0x10dd33458>,
#  <CT_R '<w:r>' at 0x10dd334a8>,
#  <CT_R '<w:r>' at 0x10dd334f8>,
#  <CT_R '<w:r>' at 0x10dd33548>,
#  <CT_R '<w:r>' at 0x10dd33598>,
#  <CT_R '<w:r>' at 0x10dd335e8>,
#  <CT_R '<w:r>' at 0x10dd33638>,
#  <CT_R '<w:r>' at 0x10dd33688>,
#  <CT_R '<w:r>' at 0x10dd336d8>,
#  <CT_R '<w:r>' at 0x10dd33728>,
#  <CT_R '<w:r>' at 0x10dd33778>,
#  <CT_R '<w:r>' at 0x10dd337c8>,
#  <CT_R '<w:r>' at 0x10dd33818>,
#  <CT_R '<w:r>' at 0x10dd33868>,
#  <CT_R '<w:r>' at 0x10dd338b8>,
#  <CT_R '<w:r>' at 0x10dd33908>,
#  <CT_R '<w:r>' at 0x10dd33958>,
#  <CT_R '<w:r>' at 0x10dd339a8>,
#  <CT_R '<w:r>' at 0x10dd339f8>,
#  <CT_R '<w:r>' at 0x10dd33a48>,
#  <CT_R '<w:r>' at 0x10dd33a98>,
#  <CT_R '<w:r>' at 0x10dd33ae8>,
#  <CT_R '<w:r>' at 0x10dd33b38>,
#  <CT_R '<w:r>' at 0x10dd33b88>,
#  <CT_R '<w:r>' at 0x10dd33bd8>,
#  <CT_R '<w:r>' at 0x10dd33c28>,
#  <CT_R '<w:r>' at 0x10dd33c78>,
#  <CT_R '<w:r>' at 0x10dd33cc8>,
#  <CT_R '<w:r>' at 0x10dd33d18>,
#  <CT_R '<w:r>' at 0x10dd33d68>,
#  <CT_R '<w:r>' at 0x10dd33db8>,
#  <CT_R '<w:r>' at 0x10dd33e08>,
#  <CT_R '<w:r>' at 0x10dd33e58>,
#  <CT_R '<w:r>' at 0x10dd33ea8>,
#  <CT_R '<w:r>' at 0x10dd33ef8>,
#  <CT_R '<w:r>' at 0x10dd33f48>,
#  <CT_R '<w:r>' at 0x10dd33f98>,
#  <CT_R '<w:r>' at 0x10dd41048>,
#  <CT_R '<w:r>' at 0x10dd41098>,
#  <CT_R '<w:r>' at 0x10dd410e8>,
#  <CT_R '<w:r>' at 0x10dd41138>,
#  <CT_R '<w:r>' at 0x10dd41188>,
#  <CT_R '<w:r>' at 0x10dd411d8>,
#  <CT_R '<w:r>' at 0x10dd41228>,
#  <CT_R '<w:r>' at 0x10dd41278>,
#  <CT_R '<w:r>' at 0x10dd412c8>,
#  <CT_R '<w:r>' at 0x10dd41318>,
#  <CT_R '<w:r>' at 0x10dd41368>,
#  <CT_R '<w:r>' at 0x10dd413b8>,
#  <CT_R '<w:r>' at 0x10dd41408>,
#  <CT_R '<w:r>' at 0x10dd41458>,
#  <CT_R '<w:r>' at 0x10dd414a8>,
#  <CT_R '<w:r>' at 0x10dd414f8>,
#  <CT_R '<w:r>' at 0x10dd41548>,
#  <CT_R '<w:r>' at 0x10dd41598>,
#  <CT_R '<w:r>' at 0x10dd415e8>,
#  <CT_R '<w:r>' at 0x10dd41638>,
#  <CT_R '<w:r>' at 0x10dd41688>,
#  <CT_R '<w:r>' at 0x10dd416d8>,
#  <CT_R '<w:r>' at 0x10dd41728>,
#  <CT_R '<w:r>' at 0x10dd41778>,
#  <CT_R '<w:r>' at 0x10dd417c8>,
#  <CT_R '<w:r>' at 0x10dd41818>,
#  <CT_R '<w:r>' at 0x10dd41868>,
#  <CT_R '<w:r>' at 0x10dd418b8>,
#  <CT_R '<w:r>' at 0x10dd41908>,
#  <CT_R '<w:r>' at 0x10dd41958>,
#  <CT_R '<w:r>' at 0x10dd419a8>,
#  <CT_R '<w:r>' at 0x10dd419f8>,
#  <CT_R '<w:r>' at 0x10dd41a48>,
#  <CT_R '<w:r>' at 0x10dd41a98>,
#  <CT_R '<w:r>' at 0x10dd41ae8>,
#  <CT_R '<w:r>' at 0x10dd41b38>,
#  <CT_R '<w:r>' at 0x10dd41b88>,
#  <CT_R '<w:r>' at 0x10dd41bd8>,
#  <CT_R '<w:r>' at 0x10dd41c28>,
#  <CT_R '<w:r>' at 0x10dd41c78>,
#  <CT_R '<w:r>' at 0x10dd41cc8>,
#  <CT_R '<w:r>' at 0x10dd41d18>,
#  <CT_R '<w:r>' at 0x10dd41d68>,
#  <CT_R '<w:r>' at 0x10dd41db8>,
#  <CT_R '<w:r>' at 0x10dd41e08>,
#  <CT_R '<w:r>' at 0x10dd41e58>,
#  <CT_R '<w:r>' at 0x10dd41ea8>,
#  <CT_R '<w:r>' at 0x10dd41ef8>,
#  <CT_R '<w:r>' at 0x10dd41f48>,
#  <CT_R '<w:r>' at 0x10dd41f98>,
#  <CT_R '<w:r>' at 0x10dd42048>,
#  <CT_R '<w:r>' at 0x10dd42098>,
#  <CT_R '<w:r>' at 0x10dd420e8>,
#  <CT_R '<w:r>' at 0x10dd42138>,
#  <CT_R '<w:r>' at 0x10dd42188>,
#  <CT_R '<w:r>' at 0x10dd421d8>,
#  <CT_R '<w:r>' at 0x10dd42228>,
#  <CT_R '<w:r>' at 0x10dd42278>,
#  <CT_R '<w:r>' at 0x10dd422c8>,
#  <CT_R '<w:r>' at 0x10dd42318>,
#  <CT_R '<w:r>' at 0x10dd42368>,
#  <CT_R '<w:r>' at 0x10dd423b8>,
#  <CT_R '<w:r>' at 0x10dd42408>,
#  <CT_R '<w:r>' at 0x10dd42458>,
#  <CT_R '<w:r>' at 0x10dd424a8>,
#  <CT_R '<w:r>' at 0x10dd424f8>,
#  <CT_R '<w:r>' at 0x10dd42548>,
#  <CT_R '<w:r>' at 0x10dd42598>,
#  <CT_R '<w:r>' at 0x10dd425e8>,
#  <CT_R '<w:r>' at 0x10dd42638>,
#  <CT_R '<w:r>' at 0x10dd42688>,
#  <CT_R '<w:r>' at 0x10dd426d8>,
#  ...]

# %%
inputfile = 'Notizen aus _Siddhartha_ eine indische Dichtung (German Edition)_.docx'
'.docx' in inputfile
# Out:
# True

# %%
import os
os.path.basename(inputfile)
os.path.abspath(inputfile)
# Out:
# '/Users/pabloherrero/Documents/ManHatTan/Notizen aus _Siddhartha_ eine indische Dichtung (German Edition)_.docx'

# %%
rsbFile = os.path.splitext(os.path.abspath(inputfile))[0]
rsbFile + '.rsb'
# Out:
# '/Users/pabloherrero/Documents/ManHatTan/Notizen aus _Siddhartha_ eine indische Dichtung (German Edition)_.rsb'

# %%
#!usr/bin/python
# -*- coding: utf-8 -*-
from docx import *
document = docx.Document(r'Notizen aus _Siddhartha_ eine indische Dichtung (German Edition)_.docx')
words = document.element.xpath('//w:r')#, namespaces=document._element.nsmap)
# words = etree.ElementBase.xpath(para._element, '//w:r', 
#                                         namespaces=para._element.nsmap)
WPML_URI = "{http://schemas.openxmlformats.org/wordprocessingml/2006/main}"
tag_rPr = WPML_URI + 'rPr'
tag_highlight = 'w:shd'
tag_val = WPML_URI + 'fill'
tag_t = WPML_URI + 't'
gold = []
blue = []
orange = []

for word in words:
    for rPr in word.findall(tag_rPr):
        high=rPr.xpath(tag_highlight)
        for hi in high:
            print(hi.attrib[tag_val])
            if hi.attrib[tag_val] == 'fde096': 
                gold.append(word.find(tag_t).text.lower())
            elif hi.attrib[tag_val] == 'ffb8a1':
                orange.append(word.find(tag_t).text.lower())
            elif hi.attrib[tag_val] == '93e3ed':
                blue.append(word.find(tag_t).text.lower())
# Out:
# auto
# 93e3ed
# 93e3ed
# 93e3ed
# ffb8a1
# ffb8a1
# 93e3ed
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# 93e3ed
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# 93e3ed
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# fde096
# fde096
# 93e3ed
# fde096
# 93e3ed
# c5e1a5
# c5e1a5
# ffb8a1
# 93e3ed
# 93e3ed
# 93e3ed
# c5e1a5
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# c5e1a5
# c5e1a5

# %% [markdown]
# ## Organize words by color in dataframe

# %%
import pandas as pd

df = pd.DataFrame([gold, blue, orange]).T
df.columns =['gold', 'blue', 'orange']
df
# Out:
#                                                  gold  \
# 0   hat je ein samana oder ein brahmane gefürchtet...
# 1   nein, denn die gehören ihm zu eigen und er gib...
# 2   sieh, kamala: wenn du einen stein ins wasser w...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
#
#                                                  blue  \
# 0   schweigend stand siddhartha im senkrechten son...
# 1   nicht einen augenblick habe ich an dir gezweif...
# 2   beraubt hat mich der buddha, dachte siddhartha...
# 3   daß siddhartha mir so fremd und unbekannt gebl...
# 4   "wenn einer eine schrift liest, deren sinn er ...
# 5   aber nie hatte er dies selbst wirklich gefunde...
# 6                                 struppiger bettler,
# 7                                            griffel,
# 8                                                laub
# 9                                             biegsam
# 10                                      müdgewordenen
# 11                                        wohlergehen
# 12                                       dienerschaft
# 13                                            predigt
# 14                                         allmählich
# 15                                            töpfers
# 16                                         schläferte
# 17                                              stets
# 18                                          beneidete
# 19                              beizulegen vermochten
# 20                                              bange
# 21                                      kindertorheit
# 22                                           schleier
# 23                                             säumen
# 24                                               ekel
# 25                                     begehrlichkeit
# 26                                        törichteste
# 27                                               tand
# 28                                         schnödeste
# 29                                              sitte
# 30                                                wut
# 31                                              frech
# 32                       verspielen und verschleudern
# 33                                            elenden
# 34                                         verhöhnend
# 35                                       gelassenheit
# 36                                            verbarg
# 37                                           geseufzt
# 38                                           inbrunst
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
#
#                                                orange
# 0                                           vorhanden
# 1                                         abgesondert
# 2                                               zehen
# 3                                               rasch
# 4                                        entschlüpfen
# 5                                            schleier
# 6                                            vielfalt
# 7                                             zuliebe
# 8                                             adliger
# 9                                          einsiedler
# 10                                        verzagtheit
# 11                                              empor
# 12                                            geballt
# 13                                           schauder
# 14                                         sichelmond
# 15                                          gesträuch
# 16                                            gesummt
# 17                                       durchdrungen
# 18                                              wesen
# 19                                           jenseits
# 20                                        waldgewölbe
# 21                                              geäst
# 22                                           begatten
# 23                                          schilfsee
# 24                                              hecht
# 25                                           ungestüm
# 26                                            mästete
# 27                                          verborgen
# 28                                              gebet
# 29                                         vorgezogen
# 30                                             befehl
# 31                                              quoll
# 32                                         schimmerte
# 33                                          begleiter
# 34                                          wohltäter
# 35                                        unterwürfig
# 36                                         lehmhütten
# 37                                            wälzten
# 38                                            balgten
# 39                                              scheu
# 40                                       segensspruch
# 41                                             bückte
# 42                                       erschauernd,
# 43                                        leichtfüßig
# 44  bist kamala, nichts andres, und in dir innen i...

# %% [markdown]
# ## Export dataframe

# %%
df.to_csv('/Users/pabloherrero/Documents/ManHatTan/Notizen aus _Siddhartha_ eine indische Dichtung (German Edition)_.out' )

# %% [markdown]
# # Others

# %% [markdown]
# ## Classify by font name

# %%
len(doc.tables), len(doc.paragraphs)
para = doc.tables[4].rows[0].cells[0].paragraphs
text = doc.tables[4].rows[0].cells[0].text
for p in para: 
    print(p.runs)
    for r in p.runs:
        print(r.text, r.font.name)
# Out:
# []
# [<docx.text.run.Run object at 0x11b06a278>]
#  None
# []
# [<docx.text.run.Run object at 0x11b06a2e8>]
# debauch Verdana
# []
# [<docx.text.run.Run object at 0x11b06a320>]
# January 17, 2019 Roboto
# [<docx.text.run.Run object at 0x11b06a978>, <docx.text.run.Run object at 0x11b06a358>, <docx.text.run.Run object at 0x11b06a470>, <docx.text.run.Run object at 0x11b06a940>, <docx.text.run.Run object at 0x11b06a438>, <docx.text.run.Run object at 0x11b06a4e0>]
#  None
#  None
#  None
# 16 None
#  None
#  None

# %% [markdown]
# #####  This way we can find different fonts: verdana, roboto...

# %% [markdown]
# ## Basic way to understand the fill classifying method

# %%
from docx import settings
doc = Document(r'Copia_Notes_from_Justine_.docx', )

words = doc.element.xpath('//w:rPr') # //w:shd to access shaded (background colored) runs
len(words), type(words[0])
# Out:
# (80, docx.oxml.text.font.CT_RPr)

# %%
res = []
for word in words:
    results = word.xpath('w:shd')
    if results != []:
        res.append(results[0].get(qn('w:fill')))
#     text = word.find(WPML_URI + 't')
res, text
# Out:
# (['93e3ed',
#   '93e3ed',
#   '93e3ed',
#   'fde096',
#   'fde096',
#   'fde096',
#   'fde096',
#   'fde096',
#   'fde096',
#   'ffb8a1',
#   'ffb8a1',
#   'ffb8a1'],
#  None)

# %%
words2 = document.element.xpath('//w:r')
for word in words2:
    if word.find(WPML_URI+'t') != None:
        print(word.find(WPML_URI+'t').text)
# Out:
# This document is overwritten when you make changes in Play Books.
# You should make a copy of this document before you edit it.
# 131 notes/highlights
# Created by Pablo Herrero
#
#  –
# Last synced June 3, 2019
# Start
# the city which used us as its flora
# —
# precipitated in us conflicts which were hers and which we mistook for our own: beloved Alexandria!
# January 7, 2019
# 4
# dauntlessly
# January 15, 2019
# 9
# debauch
# January 17, 2019
# 16
# donnish
# January 20, 2019
# 19

# %% [markdown]
# # Test rashib script

# %%
rashib = '/Users/pabloherrero/Documents/ManHatTan/playbooks_raw/Notizen aus _Siddhartha_ eine indische Dichtung (German Edition)_.docx'

words = load_docx(rashib)

cadera = classify_words_fillcolor(words)
cadera
# Out:
# Found 87 colorfilled words
#                                                  gold  \
# 0   hat je ein samana oder ein brahmane gefürchtet...
# 1   nein, denn die gehören ihm zu eigen und er gib...
# 2   sieh, kamala: wenn du einen stein ins wasser w...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
#
#                                                  blue  \
# 0   schweigend stand siddhartha im senkrechten son...
# 1   nicht einen augenblick habe ich an dir gezweif...
# 2   beraubt hat mich der buddha, dachte siddhartha...
# 3   daß siddhartha mir so fremd und unbekannt gebl...
# 4   "wenn einer eine schrift liest, deren sinn er ...
# 5   aber nie hatte er dies selbst wirklich gefunde...
# 6                                 struppiger bettler,
# 7                                            griffel,
# 8                                                laub
# 9                                             biegsam
# 10                                      müdgewordenen
# 11                                        wohlergehen
# 12                                       dienerschaft
# 13                                            predigt
# 14                                         allmählich
# 15                                            töpfers
# 16                                         schläferte
# 17                                              stets
# 18                                          beneidete
# 19                              beizulegen vermochten
# 20                                              bange
# 21                                      kindertorheit
# 22                                           schleier
# 23                                             säumen
# 24                                               ekel
# 25                                     begehrlichkeit
# 26                                        törichteste
# 27                                               tand
# 28                                         schnödeste
# 29                                              sitte
# 30                                                wut
# 31                                              frech
# 32                       verspielen und verschleudern
# 33                                            elenden
# 34                                         verhöhnend
# 35                                       gelassenheit
# 36                                            verbarg
# 37                                           geseufzt
# 38                                           inbrunst
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
#
#                                                orange
# 0                                           vorhanden
# 1                                         abgesondert
# 2                                               zehen
# 3                                               rasch
# 4                                        entschlüpfen
# 5                                            schleier
# 6                                            vielfalt
# 7                                             zuliebe
# 8                                             adliger
# 9                                          einsiedler
# 10                                        verzagtheit
# 11                                              empor
# 12                                            geballt
# 13                                           schauder
# 14                                         sichelmond
# 15                                          gesträuch
# 16                                            gesummt
# 17                                       durchdrungen
# 18                                              wesen
# 19                                           jenseits
# 20                                        waldgewölbe
# 21                                              geäst
# 22                                           begatten
# 23                                          schilfsee
# 24                                              hecht
# 25                                           ungestüm
# 26                                            mästete
# 27                                          verborgen
# 28                                              gebet
# 29                                         vorgezogen
# 30                                             befehl
# 31                                              quoll
# 32                                         schimmerte
# 33                                          begleiter
# 34                                          wohltäter
# 35                                        unterwürfig
# 36                                         lehmhütten
# 37                                            wälzten
# 38                                            balgten
# 39                                              scheu
# 40                                       segensspruch
# 41                                             bückte
# 42                                       erschauernd,
# 43                                        leichtfüßig
# 44  bist kamala, nichts andres, und in dir innen i...

# %%
def clean_filename(filename : str)->str:
    """Remove automatically added "Notes from..." string from filename"""
    filename = filename.replace(' ', '_')
    filename = filename.replace('_-_Bloc-notes', '')
    filename = filename.replace('_-_Notizbuch', '')

    filename = filename.replace('Notes_from__', '')
    filename = filename.replace('Notizen_aus__', '')

    return filename

# %%
rashib = clean_filename(rashib)

# %%
write_cadera(rashib, cadera)
# Out:
# Created CADERA file /Users/pabloherrero/Documents/ManHatTan/CADERAs/Siddhartha__eine_indische_Dichtung_(German_Edition)_.cder

# %%
def test_rashib(cadscript_path : str):
    """Test whether rashib produces the same cadera as in reference file (Siddhartha)"""

    cadref_path = '/Users/pabloherrero/Documents/ManHatTan/CADERAs/Siddhartha__eine_indische_Dichtung_(German_Edition)_.cder'
    cadref = pd.read_csv(cadref_path, index=False)
    cadscript = pd.read_csv(cadscript_path, index=False)

    compare_df = (cadscript == cadref)
    fails = np.where(compare_df == False)
    print('Found (%i,%i) row,cols replication fails at init_cadstick'%(len(fails[0]), len(fails[1]) ) )
    print('On reference file:')
    print(cadref.iloc[fails[0], fails[1]])
    print('On processed file:')
    print(cadscript.iloc[fails[0], fails[1]])

# %%
cadref_path = '/Users/pabloherrero/Documents/ManHatTan/CADERAs/Siddhartha__eine_indische_Dichtung_(German_Edition)_.cder'
cadref = pd.read_csv(cadref_path, index_col=0)
cadscript = pd.read_csv(cadscript_path, index_col=0)

compare_df = (cadscript == cadref)
fails = np.where(compare_df == False)

# %%
cadscript
# Out:
#                                                  gold  \
# 0   hat je ein samana oder ein brahmane gefürchtet...
# 1   nein, denn die gehören ihm zu eigen und er gib...
# 2   sieh, kamala: wenn du einen stein ins wasser w...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
#
#                                                  blue  \
# 0   schweigend stand siddhartha im senkrechten son...
# 1   nicht einen augenblick habe ich an dir gezweif...
# 2   beraubt hat mich der buddha, dachte siddhartha...
# 3   daß siddhartha mir so fremd und unbekannt gebl...
# 4   "wenn einer eine schrift liest, deren sinn er ...
# 5   aber nie hatte er dies selbst wirklich gefunde...
# 6                                 struppiger bettler,
# 7                                            griffel,
# 8                                                laub
# 9                                             biegsam
# 10                                      müdgewordenen
# 11                                        wohlergehen
# 12                                       dienerschaft
# 13                                            predigt
# 14                                         allmählich
# 15                                            töpfers
# 16                                         schläferte
# 17                                              stets
# 18                                          beneidete
# 19                              beizulegen vermochten
# 20                                              bange
# 21                                      kindertorheit
# 22                                           schleier
# 23                                             säumen
# 24                                               ekel
# 25                                     begehrlichkeit
# 26                                        törichteste
# 27                                               tand
# 28                                         schnödeste
# 29                                              sitte
# 30                                                wut
# 31                                              frech
# 32                       verspielen und verschleudern
# 33                                            elenden
# 34                                         verhöhnend
# 35                                       gelassenheit
# 36                                            verbarg
# 37                                           geseufzt
# 38                                           inbrunst
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
#
#                                                orange
# 0                                           vorhanden
# 1                                         abgesondert
# 2                                               zehen
# 3                                               rasch
# 4                                        entschlüpfen
# 5                                            schleier
# 6                                            vielfalt
# 7                                             zuliebe
# 8                                             adliger
# 9                                          einsiedler
# 10                                        verzagtheit
# 11                                              empor
# 12                                            geballt
# 13                                           schauder
# 14                                         sichelmond
# 15                                          gesträuch
# 16                                            gesummt
# 17                                       durchdrungen
# 18                                              wesen
# 19                                           jenseits
# 20                                        waldgewölbe
# 21                                              geäst
# 22                                           begatten
# 23                                          schilfsee
# 24                                              hecht
# 25                                           ungestüm
# 26                                            mästete
# 27                                          verborgen
# 28                                              gebet
# 29                                         vorgezogen
# 30                                             befehl
# 31                                              quoll
# 32                                         schimmerte
# 33                                          begleiter
# 34                                          wohltäter
# 35                                        unterwürfig
# 36                                         lehmhütten
# 37                                            wälzten
# 38                                            balgten
# 39                                              scheu
# 40                                       segensspruch
# 41                                             bückte
# 42                                       erschauernd,
# 43                                        leichtfüßig
# 44  bist kamala, nichts andres, und in dir innen i...

# %%
cadref
# Out:
#                                                  gold  \
# 0   hat je ein samana oder ein brahmane gefürchtet...
# 1   nein, denn die gehören ihm zu eigen und er gib...
# 2   sieh, kamala: wenn du einen stein ins wasser w...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
#
#                                                  blue  \
# 0   schweigend stand siddhartha im senkrechten son...
# 1   nicht einen augenblick habe ich an dir gezweif...
# 2   beraubt hat mich der buddha, dachte siddhartha...
# 3   daß siddhartha mir so fremd und unbekannt gebl...
# 4   "wenn einer eine schrift liest, deren sinn er ...
# 5   aber nie hatte er dies selbst wirklich gefunde...
# 6                                 struppiger bettler,
# 7                                            griffel,
# 8                                                laub
# 9                                             biegsam
# 10                                      müdgewordenen
# 11                                        wohlergehen
# 12                                       dienerschaft
# 13                                            predigt
# 14                                         allmählich
# 15                                            töpfers
# 16                                         schläferte
# 17                                              stets
# 18                                          beneidete
# 19                              beizulegen vermochten
# 20                                              bange
# 21                                      kindertorheit
# 22                                           schleier
# 23                                             säumen
# 24                                               ekel
# 25                                     begehrlichkeit
# 26                                        törichteste
# 27                                               tand
# 28                                         schnödeste
# 29                                              sitte
# 30                                                wut
# 31                                              frech
# 32                       verspielen und verschleudern
# 33                                            elenden
# 34                                         verhöhnend
# 35                                       gelassenheit
# 36                                            verbarg
# 37                                           geseufzt
# 38                                           inbrunst
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
#
#                                                orange
# 0                                           vorhanden
# 1                                         abgesondert
# 2                                               zehen
# 3                                               rasch
# 4                                        entschlüpfen
# 5                                            schleier
# 6                                            vielfalt
# 7                                             zuliebe
# 8                                             adliger
# 9                                          einsiedler
# 10                                        verzagtheit
# 11                                              empor
# 12                                            geballt
# 13                                           schauder
# 14                                         sichelmond
# 15                                          gesträuch
# 16                                            gesummt
# 17                                       durchdrungen
# 18                                              wesen
# 19                                           jenseits
# 20                                        waldgewölbe
# 21                                              geäst
# 22                                           begatten
# 23                                          schilfsee
# 24                                              hecht
# 25                                           ungestüm
# 26                                            mästete
# 27                                          verborgen
# 28                                              gebet
# 29                                         vorgezogen
# 30                                             befehl
# 31                                              quoll
# 32                                         schimmerte
# 33                                          begleiter
# 34                                          wohltäter
# 35                                        unterwürfig
# 36                                         lehmhütten
# 37                                            wälzten
# 38                                            balgten
# 39                                              scheu
# 40                                       segensspruch
# 41                                             bückte
# 42                                       erschauernd,
# 43                                        leichtfüßig
# 44  bist kamala, nichts andres, und in dir innen i...

# %%
compare_series = []
for col, colr in zip(cadref, cadscript):
    compare_series.append((cadref[col].dropna() == cadref[colr].dropna()))
compare_series.append(False)

# %%
fails = np.where(compare_series.) == False)
fails
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-2bd65a234abd> in <module>
# ----> 1 fails = np.where(compare_series.flatten() == False)
#       2 fails
#
# AttributeError: 'list' object has no attribute 'flatten'

# %%
cadscript_path = '/Users/pabloherrero/Documents/ManHatTan/CADERAs/Notizen aus _Siddhartha_ eine indische Dichtung (German Edition)_.cder'
test_rashib(cadscript_path)
# Out:
# Found (48,48) row,cols replication fails at init_cadstick
# On reference file:
#    gold gold gold gold gold gold gold gold gold gold  \
# 3   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 14  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 15  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 16  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 17  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 19  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 21  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 22  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 23  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 24  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 25  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 26  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 27  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 28  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 29  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 32  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 33  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 34  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 35  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 36  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 37  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 38  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 39  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 39  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 40  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 40  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 41  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 41  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 42  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 42  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 43  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 43  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 44  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 44  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                           ...                         gold  \
# 3                         ...                          NaN
# 4                         ...                          NaN
# 5                         ...                          NaN
# 6                         ...                          NaN
# 7                         ...                          NaN
# 8                         ...                          NaN
# 9                         ...                          NaN
# 10                        ...                          NaN
# 11                        ...                          NaN
# 12                        ...                          NaN
# 13                        ...                          NaN
# 14                        ...                          NaN
# 15                        ...                          NaN
# 16                        ...                          NaN
# 17                        ...                          NaN
# 18                        ...                          NaN
# 19                        ...                          NaN
# 20                        ...                          NaN
# 21                        ...                          NaN
# 22                        ...                          NaN
# 23                        ...                          NaN
# 24                        ...                          NaN
# 25                        ...                          NaN
# 26                        ...                          NaN
# 27                        ...                          NaN
# 28                        ...                          NaN
# 29                        ...                          NaN
# 30                        ...                          NaN
# 31                        ...                          NaN
# 32                        ...                          NaN
# 33                        ...                          NaN
# 34                        ...                          NaN
# 35                        ...                          NaN
# 36                        ...                          NaN
# 37                        ...                          NaN
# 38                        ...                          NaN
# 39                        ...                          NaN
# 39                        ...                          NaN
# 40                        ...                          NaN
# 40                        ...                          NaN
# 41                        ...                          NaN
# 41                        ...                          NaN
# 42                        ...                          NaN
# 42                        ...                          NaN
# 43                        ...                          NaN
# 43                        ...                          NaN
# 44                        ...                          NaN
# 44                        ...                          NaN
#
#                                                  blue gold  \
# 3   daß siddhartha mir so fremd und unbekannt gebl...  NaN
# 4   "wenn einer eine schrift liest, deren sinn er ...  NaN
# 5   aber nie hatte er dies selbst wirklich gefunde...  NaN
# 6                                 struppiger bettler,  NaN
# 7                                            griffel,  NaN
# 8                                                laub  NaN
# 9                                             biegsam  NaN
# 10                                      müdgewordenen  NaN
# 11                                        wohlergehen  NaN
# 12                                       dienerschaft  NaN
# 13                                            predigt  NaN
# 14                                         allmählich  NaN
# 15                                            töpfers  NaN
# 16                                         schläferte  NaN
# 17                                              stets  NaN
# 18                                          beneidete  NaN
# 19                              beizulegen vermochten  NaN
# 20                                              bange  NaN
# 21                                      kindertorheit  NaN
# 22                                           schleier  NaN
# 23                                             säumen  NaN
# 24                                               ekel  NaN
# 25                                     begehrlichkeit  NaN
# 26                                        törichteste  NaN
# 27                                               tand  NaN
# 28                                         schnödeste  NaN
# 29                                              sitte  NaN
# 30                                                wut  NaN
# 31                                              frech  NaN
# 32                       verspielen und verschleudern  NaN
# 33                                            elenden  NaN
# 34                                         verhöhnend  NaN
# 35                                       gelassenheit  NaN
# 36                                            verbarg  NaN
# 37                                           geseufzt  NaN
# 38                                           inbrunst  NaN
# 39                                                NaN  NaN
# 39                                                NaN  NaN
# 40                                                NaN  NaN
# 40                                                NaN  NaN
# 41                                                NaN  NaN
# 41                                                NaN  NaN
# 42                                                NaN  NaN
# 42                                                NaN  NaN
# 43                                                NaN  NaN
# 43                                                NaN  NaN
# 44                                                NaN  NaN
# 44                                                NaN  NaN
#
#                                                  blue gold  \
# 3   daß siddhartha mir so fremd und unbekannt gebl...  NaN
# 4   "wenn einer eine schrift liest, deren sinn er ...  NaN
# 5   aber nie hatte er dies selbst wirklich gefunde...  NaN
# 6                                 struppiger bettler,  NaN
# 7                                            griffel,  NaN
# 8                                                laub  NaN
# 9                                             biegsam  NaN
# 10                                      müdgewordenen  NaN
# 11                                        wohlergehen  NaN
# 12                                       dienerschaft  NaN
# 13                                            predigt  NaN
# 14                                         allmählich  NaN
# 15                                            töpfers  NaN
# 16                                         schläferte  NaN
# 17                                              stets  NaN
# 18                                          beneidete  NaN
# 19                              beizulegen vermochten  NaN
# 20                                              bange  NaN
# 21                                      kindertorheit  NaN
# 22                                           schleier  NaN
# 23                                             säumen  NaN
# 24                                               ekel  NaN
# 25                                     begehrlichkeit  NaN
# 26                                        törichteste  NaN
# 27                                               tand  NaN
# 28                                         schnödeste  NaN
# 29                                              sitte  NaN
# 30                                                wut  NaN
# 31                                              frech  NaN
# 32                       verspielen und verschleudern  NaN
# 33                                            elenden  NaN
# 34                                         verhöhnend  NaN
# 35                                       gelassenheit  NaN
# 36                                            verbarg  NaN
# 37                                           geseufzt  NaN
# 38                                           inbrunst  NaN
# 39                                                NaN  NaN
# 39                                                NaN  NaN
# 40                                                NaN  NaN
# 40                                                NaN  NaN
# 41                                                NaN  NaN
# 41                                                NaN  NaN
# 42                                                NaN  NaN
# 42                                                NaN  NaN
# 43                                                NaN  NaN
# 43                                                NaN  NaN
# 44                                                NaN  NaN
# 44                                                NaN  NaN
#
#                                                  blue gold  \
# 3   daß siddhartha mir so fremd und unbekannt gebl...  NaN
# 4   "wenn einer eine schrift liest, deren sinn er ...  NaN
# 5   aber nie hatte er dies selbst wirklich gefunde...  NaN
# 6                                 struppiger bettler,  NaN
# 7                                            griffel,  NaN
# 8                                                laub  NaN
# 9                                             biegsam  NaN
# 10                                      müdgewordenen  NaN
# 11                                        wohlergehen  NaN
# 12                                       dienerschaft  NaN
# 13                                            predigt  NaN
# 14                                         allmählich  NaN
# 15                                            töpfers  NaN
# 16                                         schläferte  NaN
# 17                                              stets  NaN
# 18                                          beneidete  NaN
# 19                              beizulegen vermochten  NaN
# 20                                              bange  NaN
# 21                                      kindertorheit  NaN
# 22                                           schleier  NaN
# 23                                             säumen  NaN
# 24                                               ekel  NaN
# 25                                     begehrlichkeit  NaN
# 26                                        törichteste  NaN
# 27                                               tand  NaN
# 28                                         schnödeste  NaN
# 29                                              sitte  NaN
# 30                                                wut  NaN
# 31                                              frech  NaN
# 32                       verspielen und verschleudern  NaN
# 33                                            elenden  NaN
# 34                                         verhöhnend  NaN
# 35                                       gelassenheit  NaN
# 36                                            verbarg  NaN
# 37                                           geseufzt  NaN
# 38                                           inbrunst  NaN
# 39                                                NaN  NaN
# 39                                                NaN  NaN
# 40                                                NaN  NaN
# 40                                                NaN  NaN
# 41                                                NaN  NaN
# 41                                                NaN  NaN
# 42                                                NaN  NaN
# 42                                                NaN  NaN
# 43                                                NaN  NaN
# 43                                                NaN  NaN
# 44                                                NaN  NaN
# 44                                                NaN  NaN
#
#                                                  blue gold  \
# 3   daß siddhartha mir so fremd und unbekannt gebl...  NaN
# 4   "wenn einer eine schrift liest, deren sinn er ...  NaN
# 5   aber nie hatte er dies selbst wirklich gefunde...  NaN
# 6                                 struppiger bettler,  NaN
# 7                                            griffel,  NaN
# 8                                                laub  NaN
# 9                                             biegsam  NaN
# 10                                      müdgewordenen  NaN
# 11                                        wohlergehen  NaN
# 12                                       dienerschaft  NaN
# 13                                            predigt  NaN
# 14                                         allmählich  NaN
# 15                                            töpfers  NaN
# 16                                         schläferte  NaN
# 17                                              stets  NaN
# 18                                          beneidete  NaN
# 19                              beizulegen vermochten  NaN
# 20                                              bange  NaN
# 21                                      kindertorheit  NaN
# 22                                           schleier  NaN
# 23                                             säumen  NaN
# 24                                               ekel  NaN
# 25                                     begehrlichkeit  NaN
# 26                                        törichteste  NaN
# 27                                               tand  NaN
# 28                                         schnödeste  NaN
# 29                                              sitte  NaN
# 30                                                wut  NaN
# 31                                              frech  NaN
# 32                       verspielen und verschleudern  NaN
# 33                                            elenden  NaN
# 34                                         verhöhnend  NaN
# 35                                       gelassenheit  NaN
# 36                                            verbarg  NaN
# 37                                           geseufzt  NaN
# 38                                           inbrunst  NaN
# 39                                                NaN  NaN
# 39                                                NaN  NaN
# 40                                                NaN  NaN
# 40                                                NaN  NaN
# 41                                                NaN  NaN
# 41                                                NaN  NaN
# 42                                                NaN  NaN
# 42                                                NaN  NaN
# 43                                                NaN  NaN
# 43                                                NaN  NaN
# 44                                                NaN  NaN
# 44                                                NaN  NaN
#
#                                                  blue
# 3   daß siddhartha mir so fremd und unbekannt gebl...
# 4   "wenn einer eine schrift liest, deren sinn er ...
# 5   aber nie hatte er dies selbst wirklich gefunde...
# 6                                 struppiger bettler,
# 7                                            griffel,
# 8                                                laub
# 9                                             biegsam
# 10                                      müdgewordenen
# 11                                        wohlergehen
# 12                                       dienerschaft
# 13                                            predigt
# 14                                         allmählich
# 15                                            töpfers
# 16                                         schläferte
# 17                                              stets
# 18                                          beneidete
# 19                              beizulegen vermochten
# 20                                              bange
# 21                                      kindertorheit
# 22                                           schleier
# 23                                             säumen
# 24                                               ekel
# 25                                     begehrlichkeit
# 26                                        törichteste
# 27                                               tand
# 28                                         schnödeste
# 29                                              sitte
# 30                                                wut
# 31                                              frech
# 32                       verspielen und verschleudern
# 33                                            elenden
# 34                                         verhöhnend
# 35                                       gelassenheit
# 36                                            verbarg
# 37                                           geseufzt
# 38                                           inbrunst
# 39                                                NaN
# 39                                                NaN
# 40                                                NaN
# 40                                                NaN
# 41                                                NaN
# 41                                                NaN
# 42                                                NaN
# 42                                                NaN
# 43                                                NaN
# 43                                                NaN
# 44                                                NaN
# 44                                                NaN
#
# [48 rows x 48 columns]
# On processed file:
#    gold gold gold gold gold gold gold gold gold gold  \
# 3   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 14  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 15  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 16  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 17  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 19  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 21  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 22  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 23  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 24  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 25  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 26  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 27  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 28  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 29  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 32  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 33  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 34  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 35  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 36  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 37  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 38  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 39  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 39  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 40  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 40  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 41  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 41  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 42  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 42  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 43  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 43  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 44  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 44  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                           ...                         gold  \
# 3                         ...                          NaN
# 4                         ...                          NaN
# 5                         ...                          NaN
# 6                         ...                          NaN
# 7                         ...                          NaN
# 8                         ...                          NaN
# 9                         ...                          NaN
# 10                        ...                          NaN
# 11                        ...                          NaN
# 12                        ...                          NaN
# 13                        ...                          NaN
# 14                        ...                          NaN
# 15                        ...                          NaN
# 16                        ...                          NaN
# 17                        ...                          NaN
# 18                        ...                          NaN
# 19                        ...                          NaN
# 20                        ...                          NaN
# 21                        ...                          NaN
# 22                        ...                          NaN
# 23                        ...                          NaN
# 24                        ...                          NaN
# 25                        ...                          NaN
# 26                        ...                          NaN
# 27                        ...                          NaN
# 28                        ...                          NaN
# 29                        ...                          NaN
# 30                        ...                          NaN
# 31                        ...                          NaN
# 32                        ...                          NaN
# 33                        ...                          NaN
# 34                        ...                          NaN
# 35                        ...                          NaN
# 36                        ...                          NaN
# 37                        ...                          NaN
# 38                        ...                          NaN
# 39                        ...                          NaN
# 39                        ...                          NaN
# 40                        ...                          NaN
# 40                        ...                          NaN
# 41                        ...                          NaN
# 41                        ...                          NaN
# 42                        ...                          NaN
# 42                        ...                          NaN
# 43                        ...                          NaN
# 43                        ...                          NaN
# 44                        ...                          NaN
# 44                        ...                          NaN
#
#                                                  blue gold  \
# 3   daß siddhartha mir so fremd und unbekannt gebl...  NaN
# 4   "wenn einer eine schrift liest, deren sinn er ...  NaN
# 5   aber nie hatte er dies selbst wirklich gefunde...  NaN
# 6                                 struppiger bettler,  NaN
# 7                                            griffel,  NaN
# 8                                                laub  NaN
# 9                                             biegsam  NaN
# 10                                      müdgewordenen  NaN
# 11                                        wohlergehen  NaN
# 12                                       dienerschaft  NaN
# 13                                            predigt  NaN
# 14                                         allmählich  NaN
# 15                                            töpfers  NaN
# 16                                         schläferte  NaN
# 17                                              stets  NaN
# 18                                          beneidete  NaN
# 19                              beizulegen vermochten  NaN
# 20                                              bange  NaN
# 21                                      kindertorheit  NaN
# 22                                           schleier  NaN
# 23                                             säumen  NaN
# 24                                               ekel  NaN
# 25                                     begehrlichkeit  NaN
# 26                                        törichteste  NaN
# 27                                               tand  NaN
# 28                                         schnödeste  NaN
# 29                                              sitte  NaN
# 30                                                wut  NaN
# 31                                              frech  NaN
# 32                       verspielen und verschleudern  NaN
# 33                                            elenden  NaN
# 34                                         verhöhnend  NaN
# 35                                       gelassenheit  NaN
# 36                                            verbarg  NaN
# 37                                           geseufzt  NaN
# 38                                           inbrunst  NaN
# 39                                                NaN  NaN
# 39                                                NaN  NaN
# 40                                                NaN  NaN
# 40                                                NaN  NaN
# 41                                                NaN  NaN
# 41                                                NaN  NaN
# 42                                                NaN  NaN
# 42                                                NaN  NaN
# 43                                                NaN  NaN
# 43                                                NaN  NaN
# 44                                                NaN  NaN
# 44                                                NaN  NaN
#
#                                                  blue gold  \
# 3   daß siddhartha mir so fremd und unbekannt gebl...  NaN
# 4   "wenn einer eine schrift liest, deren sinn er ...  NaN
# 5   aber nie hatte er dies selbst wirklich gefunde...  NaN
# 6                                 struppiger bettler,  NaN
# 7                                            griffel,  NaN
# 8                                                laub  NaN
# 9                                             biegsam  NaN
# 10                                      müdgewordenen  NaN
# 11                                        wohlergehen  NaN
# 12                                       dienerschaft  NaN
# 13                                            predigt  NaN
# 14                                         allmählich  NaN
# 15                                            töpfers  NaN
# 16                                         schläferte  NaN
# 17                                              stets  NaN
# 18                                          beneidete  NaN
# 19                              beizulegen vermochten  NaN
# 20                                              bange  NaN
# 21                                      kindertorheit  NaN
# 22                                           schleier  NaN
# 23                                             säumen  NaN
# 24                                               ekel  NaN
# 25                                     begehrlichkeit  NaN
# 26                                        törichteste  NaN
# 27                                               tand  NaN
# 28                                         schnödeste  NaN
# 29                                              sitte  NaN
# 30                                                wut  NaN
# 31                                              frech  NaN
# 32                       verspielen und verschleudern  NaN
# 33                                            elenden  NaN
# 34                                         verhöhnend  NaN
# 35                                       gelassenheit  NaN
# 36                                            verbarg  NaN
# 37                                           geseufzt  NaN
# 38                                           inbrunst  NaN
# 39                                                NaN  NaN
# 39                                                NaN  NaN
# 40                                                NaN  NaN
# 40                                                NaN  NaN
# 41                                                NaN  NaN
# 41                                                NaN  NaN
# 42                                                NaN  NaN
# 42                                                NaN  NaN
# 43                                                NaN  NaN
# 43                                                NaN  NaN
# 44                                                NaN  NaN
# 44                                                NaN  NaN
#
#                                                  blue gold  \
# 3   daß siddhartha mir so fremd und unbekannt gebl...  NaN
# 4   "wenn einer eine schrift liest, deren sinn er ...  NaN
# 5   aber nie hatte er dies selbst wirklich gefunde...  NaN
# 6                                 struppiger bettler,  NaN
# 7                                            griffel,  NaN
# 8                                                laub  NaN
# 9                                             biegsam  NaN
# 10                                      müdgewordenen  NaN
# 11                                        wohlergehen  NaN
# 12                                       dienerschaft  NaN
# 13                                            predigt  NaN
# 14                                         allmählich  NaN
# 15                                            töpfers  NaN
# 16                                         schläferte  NaN
# 17                                              stets  NaN
# 18                                          beneidete  NaN
# 19                              beizulegen vermochten  NaN
# 20                                              bange  NaN
# 21                                      kindertorheit  NaN
# 22                                           schleier  NaN
# 23                                             säumen  NaN
# 24                                               ekel  NaN
# 25                                     begehrlichkeit  NaN
# 26                                        törichteste  NaN
# 27                                               tand  NaN
# 28                                         schnödeste  NaN
# 29                                              sitte  NaN
# 30                                                wut  NaN
# 31                                              frech  NaN
# 32                       verspielen und verschleudern  NaN
# 33                                            elenden  NaN
# 34                                         verhöhnend  NaN
# 35                                       gelassenheit  NaN
# 36                                            verbarg  NaN
# 37                                           geseufzt  NaN
# 38                                           inbrunst  NaN
# 39                                                NaN  NaN
# 39                                                NaN  NaN
# 40                                                NaN  NaN
# 40                                                NaN  NaN
# 41                                                NaN  NaN
# 41                                                NaN  NaN
# 42                                                NaN  NaN
# 42                                                NaN  NaN
# 43                                                NaN  NaN
# 43                                                NaN  NaN
# 44                                                NaN  NaN
# 44                                                NaN  NaN
#
#                                                  blue gold  \
# 3   daß siddhartha mir so fremd und unbekannt gebl...  NaN
# 4   "wenn einer eine schrift liest, deren sinn er ...  NaN
# 5   aber nie hatte er dies selbst wirklich gefunde...  NaN
# 6                                 struppiger bettler,  NaN
# 7                                            griffel,  NaN
# 8                                                laub  NaN
# 9                                             biegsam  NaN
# 10                                      müdgewordenen  NaN
# 11                                        wohlergehen  NaN
# 12                                       dienerschaft  NaN
# 13                                            predigt  NaN
# 14                                         allmählich  NaN
# 15                                            töpfers  NaN
# 16                                         schläferte  NaN
# 17                                              stets  NaN
# 18                                          beneidete  NaN
# 19                              beizulegen vermochten  NaN
# 20                                              bange  NaN
# 21                                      kindertorheit  NaN
# 22                                           schleier  NaN
# 23                                             säumen  NaN
# 24                                               ekel  NaN
# 25                                     begehrlichkeit  NaN
# 26                                        törichteste  NaN
# 27                                               tand  NaN
# 28                                         schnödeste  NaN
# 29                                              sitte  NaN
# 30                                                wut  NaN
# 31                                              frech  NaN
# 32                       verspielen und verschleudern  NaN
# 33                                            elenden  NaN
# 34                                         verhöhnend  NaN
# 35                                       gelassenheit  NaN
# 36                                            verbarg  NaN
# 37                                           geseufzt  NaN
# 38                                           inbrunst  NaN
# 39                                                NaN  NaN
# 39                                                NaN  NaN
# 40                                                NaN  NaN
# 40                                                NaN  NaN
# 41                                                NaN  NaN
# 41                                                NaN  NaN
# 42                                                NaN  NaN
# 42                                                NaN  NaN
# 43                                                NaN  NaN
# 43                                                NaN  NaN
# 44                                                NaN  NaN
# 44                                                NaN  NaN
#
#                                                  blue
# 3   daß siddhartha mir so fremd und unbekannt gebl...
# 4   "wenn einer eine schrift liest, deren sinn er ...
# 5   aber nie hatte er dies selbst wirklich gefunde...
# 6                                 struppiger bettler,
# 7                                            griffel,
# 8                                                laub
# 9                                             biegsam
# 10                                      müdgewordenen
# 11                                        wohlergehen
# 12                                       dienerschaft
# 13                                            predigt
# 14                                         allmählich
# 15                                            töpfers
# 16                                         schläferte
# 17                                              stets
# 18                                          beneidete
# 19                              beizulegen vermochten
# 20                                              bange
# 21                                      kindertorheit
# 22                                           schleier
# 23                                             säumen
# 24                                               ekel
# 25                                     begehrlichkeit
# 26                                        törichteste
# 27                                               tand
# 28                                         schnödeste
# 29                                              sitte
# 30                                                wut
# 31                                              frech
# 32                       verspielen und verschleudern
# 33                                            elenden
# 34                                         verhöhnend
# 35                                       gelassenheit
# 36                                            verbarg
# 37                                           geseufzt
# 38                                           inbrunst
# 39                                                NaN
# 39                                                NaN
# 40                                                NaN
# 40                                                NaN
# 41                                                NaN
# 41                                                NaN
# 42                                                NaN
# 42                                                NaN
# 43                                                NaN
# 43                                                NaN
# 44                                                NaN
# 44                                                NaN
#
# [48 rows x 48 columns]
