# %%
import apertium
import re

# %% [markdown]
# # Checking Apertium

# %%
word_en = apertium.translate('de', 'en', 'unwillkürlich')
apertium.analyze('en', 'indifference')
word_de = apertium.translate('en', 'de', 'indifference')
word_de
# Out:
# 'Gleichgültigkeit'

# %%
that = apertium.analyze('en', 'that')

# re.finditer('\\//', that[0])
that[0].readings, that[0].lexical_unit, that[0].wordform
# Out:
# ([[SReading(baseform='that', tags=['cnjsub'])],
#   [SReading(baseform='that', tags=['det', 'dem', 'sg'])],
#   [SReading(baseform='that', tags=['prn', 'dem', 'mf', 'sg'])],
#   [SReading(baseform='that', tags=['prn', 'rel', 'an', 'mf', 'sp'])]],
#  'that/that<cnjsub>/that<det><dem><sg>/that<prn><dem><mf><sg>/that<prn><rel><an><mf><sp>',
#  'that')

# %%
type(that[0])
# Out:
# streamparser.LexicalUnit

# %%
apertium.tagger.tag('en', 'screens')[0].readings[0][0].baseform
# Out:
# 'screen'

# %%
screens = apertium.analyze('en', 'screens')
screens[0].readings, screens[0].wordform
# Out:
# ([[SReading(baseform='screen', tags=['n', 'pl'])],
#   [SReading(baseform='screen', tags=['vblex', 'pres', 'p3', 'sg'])]],
#  'screens')

# %%
screens[0].readings[0][0].baseform
# Out:
# 'screen'

# %%
elenden = apertium.analyze('de', 'elenden')
elenden[0].readings[0][0], elenden[0].wordform
# Out:
# (SReading(baseform='elend', tags=['adj', 'sint', 'm', 'sg', 'gen', 'st']),
#  'elenden')

# %%
gleichgultigkeit = apertium.analyze('de', 'gleichgültigkeit')
gleichgultigkeit[0].readings
# Out:
# [[SReading(baseform='gleichgültigkeit', tags=['n', 'f', 'sg', 'nom', 'lower'])],
#  [SReading(baseform='gleichgültigkeit', tags=['n', 'f', 'sg', 'gen', 'lower'])],
#  [SReading(baseform='gleichgültigkeit', tags=['n', 'f', 'sg', 'dat', 'lower'])],
#  [SReading(baseform='gleichgültigkeit', tags=['n', 'f', 'sg', 'acc', 'lower'])],
#  [SReading(baseform='gleichgültigkeit', tags=['n', 'f', 'sg', 'nom', 'lower'])],
#  [SReading(baseform='gleichgültigkeit', tags=['n', 'f', 'sg', 'gen', 'lower'])],
#  [SReading(baseform='gleichgültigkeit', tags=['n', 'f', 'sg', 'dat', 'lower'])],
#  [SReading(baseform='gleichgültigkeit', tags=['n', 'f', 'sg', 'acc', 'lower'])]]

# %% [markdown]
# ## Italiano

# %%
word_it = apertium.translate('it', 'en', 'grosso')
word_it
# Out:
# 'Thick'

# %%
word_it = apertium.translate('es', 'it', 'cat')
word_it
# Out:
# ---------------------------------------------------------------------------
# ModeNotInstalled                          Traceback (most recent call last)
# <ipython-input-89-08e783354c3e> in <module>
# ----> 1 word_it = apertium.translate('es', 'it', 'cat')
#       2 word_it
#
# ~/anaconda3/lib/python3.7/site-packages/apertium/translation/__init__.py in translate(l1, l2, text, mark_unknown, formatting, deformat, reformat)
#     185     """
#     186     translator = Translator(l1, l2)
# --> 187     return translator.translate(text, mark_unknown, formatting, deformat, reformat)
#
# ~/anaconda3/lib/python3.7/site-packages/apertium/translation/__init__.py in translate(self, text, mark_unknown, formatting, deformat, reformat)
#     159             pair = map(to_alpha3_code, [self.l1, self.l2])
#     160         else:
# --> 161             raise apertium.ModeNotInstalled()
#     162
#     163         if pair is not None:
#
# ModeNotInstalled:

# %% [markdown]
# # LIPSTICK implementation

# %%
import pandas as pd
import matplotlib.pyplot as plt
from copy import deepcopy
lippath = '../LIPSTICK/Die_Verwandlung.lip'

lips = pd.read_csv(lippath, index_col=False)

# %% [markdown]
# ## Correct LIPSTICK:
# (Had user_id field missing): add it manually

# %%
lips['user_id2'] = 'pablo'  # Will be customizable later
lips
# Out:
#      p_recall     timestamp      delta user_id learning_language ui_language  \
# 0    1.090909  1.588241e+09   850388.0   pablo                de          en
# 1    1.000000  1.588262e+09   871118.0   pablo                de          en
# 2    1.125000  1.588247e+09   855813.0   pablo                de          en
# 3    1.142857  1.588266e+09   874813.0   pablo                de          en
# 4    1.111111  1.588243e+09   852194.0   pablo                de          en
# 5    1.111111  1.588176e+09   784818.0   pablo                de          en
# 6    1.076923  1.588431e+09  1040042.0   pablo                de          en
# 7    0.909091  1.588268e+09   876619.0   pablo                de          en
# 8    1.111111  1.588245e+09   854001.0   pablo                de          en
# 9    1.090909  1.588239e+09   848581.0   pablo                de          en
# 10   0.250000  1.587391e+09        0.0   pablo                de          en
# 11   1.000000  1.587391e+09        0.0   pablo                de          en
# 12   0.500000  1.587391e+09        0.0   pablo                de          en
# 13   0.200000  1.587391e+09        0.0   pablo                de          en
# 14   1.000000  1.587391e+09        0.0   pablo                de          en
# 15   1.000000  1.588067e+09   676047.0   pablo                de          en
# 16   0.166667  1.587391e+09        0.0   pablo                de          en
# 17   0.750000  1.587391e+09        0.0   pablo                de          en
# 18   0.333333  1.587391e+09        0.0   pablo                de          en
# 19   0.250000  1.587391e+09        0.0   pablo                de          en
# 20   0.500000  1.587391e+09        0.0   pablo                de          en
# 21        inf  1.587391e+09        0.0   pablo                de          en
# 22   1.000000  1.587391e+09        0.0   pablo                de          en
# 23   0.500000  1.587391e+09        0.0   pablo                de          en
# 24   0.500000  1.587391e+09        0.0   pablo                de          en
# 25   0.500000  1.587391e+09        0.0   pablo                de          en
# 26   1.000000  1.587391e+09        0.0   pablo                de          en
# 27   0.500000  1.587391e+09        0.0   pablo                de          en
# 28   1.000000  1.587391e+09        0.0   pablo                de          en
# 29   1.000000  1.587391e+09        0.0   pablo                de          en
# ..        ...           ...        ...     ...               ...         ...
# 74   0.500000  1.587391e+09        0.0   pablo                de          en
# 75   0.500000  1.587391e+09        0.0   pablo                de          en
# 76   0.666667  1.587391e+09        0.0   pablo                de          en
# 77   0.666667  1.587391e+09        0.0   pablo                de          en
# 78   1.000000  1.587391e+09        0.0   pablo                de          en
# 79   1.000000  1.587391e+09        0.0   pablo                de          en
# 80   0.500000  1.587391e+09        0.0   pablo                de          en
# 81   1.000000  1.587391e+09        0.0   pablo                de          en
# 82   0.500000  1.587391e+09        0.0   pablo                de          en
# 83   0.200000  1.587391e+09        0.0   pablo                de          en
# 84   0.666667  1.587391e+09        0.0   pablo                de          en
# 85   0.500000  1.587391e+09        0.0   pablo                de          en
# 86   0.333333  1.587391e+09        0.0   pablo                de          en
# 87   0.400000  1.587391e+09        0.0   pablo                de          en
# 88   0.200000  1.587391e+09        0.0   pablo                de          en
# 89   0.333333  1.587391e+09        0.0   pablo                de          en
# 90   0.428571  1.587391e+09        0.0   pablo                de          en
# 91   0.142857  1.587391e+09        0.0   pablo                de          en
# 92   0.333333  1.587391e+09        0.0   pablo                de          en
# 93   0.500000  1.587391e+09        0.0   pablo                de          en
# 94   0.200000  1.587391e+09        0.0   pablo                de          en
# 95   0.400000  1.587391e+09        0.0   pablo                de          en
# 96   0.500000  1.587391e+09        0.0   pablo                de          en
# 97   1.000000  1.587391e+09        0.0   pablo                de          en
# 98   0.500000  1.587391e+09        0.0   pablo                de          en
# 99   0.500000  1.587391e+09        0.0   pablo                de          en
# 100  0.500000  1.587391e+09        0.0   pablo                de          en
# 101  0.500000  1.587391e+09        0.0   pablo                de          en
# 102  1.000000  1.587391e+09        0.0   pablo                de          en
# 103       NaN  1.588264e+09   873007.0     NaN               NaN         NaN
#
#                word_ll            word_ul                     lexeme_string  \
# 0             billigte           approved  lernt/lernen<vblex><pri><p3><sg>
# 1     Gleichgültigkeit       indifference  lernt/lernen<vblex><pri><p3><sg>
# 2           Ungeziefer             vermin  lernt/lernen<vblex><pri><p3><sg>
# 3                Ärmel            sleeves  lernt/lernen<vblex><pri><p3><sg>
# 4           Schluchzen               sobs  lernt/lernen<vblex><pri><p3><sg>
# 5           flimmerten          flickered  lernt/lernen<vblex><pri><p3><sg>
# 6           ausgerückt         disengaged  lernt/lernen<vblex><pri><p3><sg>
# 7           schluchzen                sob  lernt/lernen<vblex><pri><p3><sg>
# 8              Rändern              edges  lernt/lernen<vblex><pri><p3><sg>
# 9         verständigen        communicate  lernt/lernen<vblex><pri><p3><sg>
# 10               Krach              crash  lernt/lernen<vblex><pri><p3><sg>
# 11     Vernunftgründen  rationalarguments  lernt/lernen<vblex><pri><p3><sg>
# 12       arbeitsscheue           work-shy  lernt/lernen<vblex><pri><p3><sg>
# 13       0.0olgedessen        As a result  lernt/lernen<vblex><pri><p3><sg>
# 14           Eigensinn          obstinacy  lernt/lernen<vblex><pri><p3><sg>
# 15         ausführlich           indetail  lernt/lernen<vblex><pri><p3><sg>
# 16          allmählich          gradually  lernt/lernen<vblex><pri><p3><sg>
# 17       Versteifungen         stiffeners  lernt/lernen<vblex><pri><p3><sg>
# 18        Fensterblech        Windowsheet  lernt/lernen<vblex><pri><p3><sg>
# 19            gebührte           deserved  lernt/lernen<vblex><pri><p3><sg>
# 20         überdrüssig              tired  lernt/lernen<vblex><pri><p3><sg>
# 21               Trotz            Despite  lernt/lernen<vblex><pri><p3><sg>
# 22           entbehren           dispense  lernt/lernen<vblex><pri><p3><sg>
# 23              wütend              angry  lernt/lernen<vblex><pri><p3><sg>
# 24            Rückgrat           backbone  lernt/lernen<vblex><pri><p3><sg>
# 25              Kiefer             Kiefer  lernt/lernen<vblex><pri><p3><sg>
# 26           gefährdet         endangered  lernt/lernen<vblex><pri><p3><sg>
# 27   ohnmachtähnlichen    faintingsimilar  lernt/lernen<vblex><pri><p3><sg>
# 28            Schonung         protection  lernt/lernen<vblex><pri><p3><sg>
# 29         vorbehalten           reserved  lernt/lernen<vblex><pri><p3><sg>
# ..                 ...                ...                               ...
# 74               Narbe               scar  lernt/lernen<vblex><pri><p3><sg>
# 75               plump              plump  lernt/lernen<vblex><pri><p3><sg>
# 76          Aufenthalt               stay  lernt/lernen<vblex><pri><p3><sg>
# 77          schaukelte             rocked  lernt/lernen<vblex><pri><p3><sg>
# 78            Sehkraft           eyesight  lernt/lernen<vblex><pri><p3><sg>
# 79        unweigerlich         inevitably  lernt/lernen<vblex><pri><p3><sg>
# 80        mannigfachen           manifold  lernt/lernen<vblex><pri><p3><sg>
# 81           endgültig              final  lernt/lernen<vblex><pri><p3><sg>
# 82              hinken                lag  lernt/lernen<vblex><pri><p3><sg>
# 83             Willkür      arbitrariness  lernt/lernen<vblex><pri><p3><sg>
# 84              Umfang              scope  lernt/lernen<vblex><pri><p3><sg>
# 85             Abscheu            disgust  lernt/lernen<vblex><pri><p3><sg>
# 86             scheute             spared  lernt/lernen<vblex><pri><p3><sg>
# 87            Ohnmacht           fainting  lernt/lernen<vblex><pri><p3><sg>
# 88           tüchtigen          efficient  lernt/lernen<vblex><pri><p3><sg>
# 89          anstarrten            staring  lernt/lernen<vblex><pri><p3><sg>
# 90            ererbten          inherited  lernt/lernen<vblex><pri><p3><sg>
# 91           erzielten           achieved  lernt/lernen<vblex><pri><p3><sg>
# 92           verzehrte           consumed  lernt/lernen<vblex><pri><p3><sg>
# 93            Einwände         objections  lernt/lernen<vblex><pri><p3><sg>
# 94              söhnte         reconciled  lernt/lernen<vblex><pri><p3><sg>
# 95       verständigten             agreed  lernt/lernen<vblex><pri><p3><sg>
# 96         besänftigen            appease  lernt/lernen<vblex><pri><p3><sg>
# 97              wehren             defend  lernt/lernen<vblex><pri><p3><sg>
# 98              Zeiger            pointer  lernt/lernen<vblex><pri><p3><sg>
# 99         Ungewißheit        uncertainty  lernt/lernen<vblex><pri><p3><sg>
# 100         Munterkeit       cheerfulness  lernt/lernen<vblex><pri><p3><sg>
# 101           weigerte            refused  lernt/lernen<vblex><pri><p3><sg>
# 102             rührte            touched  lernt/lernen<vblex><pri><p3><sg>
# 103                NaN                NaN                               NaN
#
#      history_seen  history_correct  session_seen  session_correct    p_pred  \
# 0            22.0             24.0           2.0              0.0  0.999900
# 1            11.0             11.0           1.0              0.0  0.023497
# 2             8.0              9.0           1.0              0.0  0.000100
# 3             7.0              8.0           2.0              1.0  0.999900
# 4             9.0             10.0           2.0              1.0  0.000100
# 5             9.0             10.0           1.0              0.0  0.004394
# 6            13.0             14.0           1.0              0.0  0.000100
# 7            11.0             10.0           1.0              0.0  0.000100
# 8             9.0             10.0           2.0              1.0  0.999900
# 9            11.0             12.0           1.0              0.0  0.001656
# 10            3.0              4.0           1.0              0.0  0.999900
# 11            3.0              4.0           4.0              3.0  0.999900
# 12            1.0              2.0           1.0              0.0  0.007931
# 13            4.0              5.0           1.0              0.0  0.000100
# 14            1.0              2.0           2.0              1.0  0.999900
# 15            3.0              3.0           2.0              1.0  0.999900
# 16            5.0              6.0           1.0              0.0  0.001213
# 17            3.0              4.0           3.0              2.0  0.000100
# 18            2.0              3.0           1.0              0.0  0.000100
# 19            3.0              4.0           1.0              0.0  0.003632
# 20            1.0              2.0           1.0              0.0  0.007047
# 21            1.0              0.0           2.0             -1.0  0.999900
# 22            1.0              2.0           2.0              1.0  0.999900
# 23            1.0              2.0           1.0              0.0  0.023437
# 24            1.0              2.0           1.0              0.0  0.004060
# 25            1.0              2.0           1.0              0.0  0.003329
# 26            1.0              2.0           2.0              1.0  0.999900
# 27            1.0              2.0           1.0              0.0  0.001548
# 28            1.0              2.0           2.0              1.0  0.999900
# 29            1.0              2.0           2.0              1.0  0.999900
# ..            ...              ...           ...              ...       ...
# 74            1.0              2.0           1.0              0.0  0.001679
# 75            1.0              2.0           1.0              0.0  0.023567
# 76            4.0              3.0           2.0             -1.0  0.025782
# 77            2.0              3.0           2.0              1.0  0.024506
# 78            2.0              3.0           3.0              2.0  0.999900
# 79            1.0              2.0           2.0              1.0  0.999900
# 80            1.0              2.0           1.0              0.0  0.002277
# 81            1.0              2.0           2.0              1.0  0.999900
# 82            1.0              2.0           1.0              0.0  0.003801
# 83            5.0              5.0           1.0              0.0  0.000100
# 84            7.0              6.0           4.0              1.0  0.000100
# 85            7.0              6.0           3.0              0.0  0.000100
# 86            7.0              6.0           2.0             -1.0  0.000100
# 87           13.0             10.0           4.0             -1.0  0.000110
# 88            6.0              5.0           1.0              0.0  0.000100
# 89            3.0              3.0           1.0              0.0  0.000100
# 90            9.0              7.0           3.0              0.0  0.000100
# 91            9.0              7.0           1.0              0.0  0.000100
# 92            8.0              6.0           2.0             -1.0  0.000100
# 93           12.0              8.0           4.0             -1.0  0.000100
# 94            7.0              5.0           1.0              0.0  0.000100
# 95            7.0              5.0           2.0             -1.0  0.000100
# 96            9.0              6.0           3.0              0.0  0.000100
# 97            2.0              2.0           2.0              1.0  0.999900
# 98            2.0              2.0           1.0              0.0  0.000100
# 99            2.0              2.0           1.0              0.0  0.000100
# 100           2.0              2.0           1.0              0.0  0.001708
# 101           3.0              2.0           1.0              0.0  0.002237
# 102           3.0              2.0           2.0             -1.0  0.999900
# 103           NaN              NaN           NaN              NaN       NaN
#
#     user_id2
# 0      pablo
# 1      pablo
# 2      pablo
# 3      pablo
# 4      pablo
# 5      pablo
# 6      pablo
# 7      pablo
# 8      pablo
# 9      pablo
# 10     pablo
# 11     pablo
# 12     pablo
# 13     pablo
# 14     pablo
# 15     pablo
# 16     pablo
# 17     pablo
# 18     pablo
# 19     pablo
# 20     pablo
# 21     pablo
# 22     pablo
# 23     pablo
# 24     pablo
# 25     pablo
# 26     pablo
# 27     pablo
# 28     pablo
# 29     pablo
# ..       ...
# 74     pablo
# 75     pablo
# 76     pablo
# 77     pablo
# 78     pablo
# 79     pablo
# 80     pablo
# 81     pablo
# 82     pablo
# 83     pablo
# 84     pablo
# 85     pablo
# 86     pablo
# 87     pablo
# 88     pablo
# 89     pablo
# 90     pablo
# 91     pablo
# 92     pablo
# 93     pablo
# 94     pablo
# 95     pablo
# 96     pablo
# 97     pablo
# 98     pablo
# 99     pablo
# 100    pablo
# 101    pablo
# 102    pablo
# 103    pablo
#
# [104 rows x 15 columns]

# %%
cols = lips.columns.tolist()
cols = cols[:3] + [cols[-1]] + cols[3:-1]

# %%
lips = lips[cols]
lips.to_csv(lippath, index=False)

# %% [markdown]
# ### Also switch word_ll and word_ul columns

# %%
# lips.word_ll, lips.word_ul =  lips.word_ul, lips.word_ll
buffer = deepcopy(lips.word_ll)
lips.word_ll = lips.word_ul
lips.word_ul = buffer
lips
# Out:
#      p_recall   timestamp   delta user_id learning_language ui_language  \
# 0    0.117647  1587891645  500746   pablo                de          en
# 1    0.200000  1587390899       0   pablo                de          en
# 2    0.200000  1587390899       0   pablo                de          en
# 3    0.666667  1587390899       0   pablo                de          en
# 4    0.285714  1587390899       0   pablo                de          en
# 5    0.142857  1587390899       0   pablo                de          en
# 6    0.166667  1587390899       0   pablo                de          en
# 7    0.200000  1587390899       0   pablo                de          en
# 8    0.285714  1587390899       0   pablo                de          en
# 9    0.250000  1587390899       0   pablo                de          en
# 10   0.250000  1587390899       0   pablo                de          en
# 11   1.000000  1587390899       0   pablo                de          en
# 12   0.500000  1587390899       0   pablo                de          en
# 13   0.200000  1587390899       0   pablo                de          en
# 14   1.000000  1587390899       0   pablo                de          en
# 15   0.666667  1587390899       0   pablo                de          en
# 16   0.166667  1587390899       0   pablo                de          en
# 17   0.750000  1587390899       0   pablo                de          en
# 18   0.333333  1587390899       0   pablo                de          en
# 19   0.250000  1587390899       0   pablo                de          en
# 20   0.500000  1587390899       0   pablo                de          en
# 21        inf  1587390899       0   pablo                de          en
# 22   1.000000  1587390899       0   pablo                de          en
# 23   0.500000  1587390899       0   pablo                de          en
# 24   0.500000  1587390899       0   pablo                de          en
# 25   0.500000  1587390899       0   pablo                de          en
# 26   1.000000  1587390899       0   pablo                de          en
# 27   0.500000  1587390899       0   pablo                de          en
# 28   1.000000  1587390899       0   pablo                de          en
# 29   1.000000  1587390899       0   pablo                de          en
# ..        ...         ...     ...     ...               ...         ...
# 73   1.000000  1587390899       0   pablo                de          en
# 74   0.500000  1587390899       0   pablo                de          en
# 75   0.500000  1587390899       0   pablo                de          en
# 76   0.666667  1587390899       0   pablo                de          en
# 77   0.666667  1587390899       0   pablo                de          en
# 78   1.000000  1587390899       0   pablo                de          en
# 79   1.000000  1587390899       0   pablo                de          en
# 80   0.500000  1587390899       0   pablo                de          en
# 81   1.000000  1587390899       0   pablo                de          en
# 82   0.500000  1587390899       0   pablo                de          en
# 83   0.200000  1587390899       0   pablo                de          en
# 84   0.666667  1587390899       0   pablo                de          en
# 85   0.500000  1587390899       0   pablo                de          en
# 86   0.333333  1587390899       0   pablo                de          en
# 87   0.400000  1587390899       0   pablo                de          en
# 88   0.200000  1587390899       0   pablo                de          en
# 89   0.333333  1587390899       0   pablo                de          en
# 90   0.428571  1587390899       0   pablo                de          en
# 91   0.142857  1587390899       0   pablo                de          en
# 92   0.333333  1587390899       0   pablo                de          en
# 93   0.500000  1587390899       0   pablo                de          en
# 94   0.200000  1587390899       0   pablo                de          en
# 95   0.400000  1587390899       0   pablo                de          en
# 96   0.500000  1587390899       0   pablo                de          en
# 97   1.000000  1587390899       0   pablo                de          en
# 98   0.500000  1587390899       0   pablo                de          en
# 99   0.500000  1587390899       0   pablo                de          en
# 100  0.500000  1587390899       0   pablo                de          en
# 101  0.500000  1587390899       0   pablo                de          en
# 102  1.000000  1587390899       0   pablo                de          en
#
#                word_ll            word_ul                     lexeme_string  \
# 0             billigte           approved  lernt/lernen<vblex><pri><p3><sg>
# 1     Gleichgültigkeit       indifference  lernt/lernen<vblex><pri><p3><sg>
# 2           Ungeziefer             vermin  lernt/lernen<vblex><pri><p3><sg>
# 3                Ärmel            sleeves  lernt/lernen<vblex><pri><p3><sg>
# 4           Schluchzen               sobs  lernt/lernen<vblex><pri><p3><sg>
# 5           flimmerten          flickered  lernt/lernen<vblex><pri><p3><sg>
# 6           ausgerückt         disengaged  lernt/lernen<vblex><pri><p3><sg>
# 7           schluchzen                sob  lernt/lernen<vblex><pri><p3><sg>
# 8              Rändern              edges  lernt/lernen<vblex><pri><p3><sg>
# 9         verständigen        communicate  lernt/lernen<vblex><pri><p3><sg>
# 10               Krach              crash  lernt/lernen<vblex><pri><p3><sg>
# 11     Vernunftgründen  rationalarguments  lernt/lernen<vblex><pri><p3><sg>
# 12       arbeitsscheue           work-shy  lernt/lernen<vblex><pri><p3><sg>
# 13       0.0olgedessen        As a result  lernt/lernen<vblex><pri><p3><sg>
# 14           Eigensinn          obstinacy  lernt/lernen<vblex><pri><p3><sg>
# 15         ausführlich           indetail  lernt/lernen<vblex><pri><p3><sg>
# 16          allmählich          gradually  lernt/lernen<vblex><pri><p3><sg>
# 17       Versteifungen         stiffeners  lernt/lernen<vblex><pri><p3><sg>
# 18        Fensterblech        Windowsheet  lernt/lernen<vblex><pri><p3><sg>
# 19            gebührte           deserved  lernt/lernen<vblex><pri><p3><sg>
# 20         überdrüssig              tired  lernt/lernen<vblex><pri><p3><sg>
# 21               Trotz            Despite  lernt/lernen<vblex><pri><p3><sg>
# 22           entbehren           dispense  lernt/lernen<vblex><pri><p3><sg>
# 23              wütend              angry  lernt/lernen<vblex><pri><p3><sg>
# 24            Rückgrat           backbone  lernt/lernen<vblex><pri><p3><sg>
# 25              Kiefer             Kiefer  lernt/lernen<vblex><pri><p3><sg>
# 26           gefährdet         endangered  lernt/lernen<vblex><pri><p3><sg>
# 27   ohnmachtähnlichen    faintingsimilar  lernt/lernen<vblex><pri><p3><sg>
# 28            Schonung         protection  lernt/lernen<vblex><pri><p3><sg>
# 29         vorbehalten           reserved  lernt/lernen<vblex><pri><p3><sg>
# ..                 ...                ...                               ...
# 73      undurchführbar      impracticable  lernt/lernen<vblex><pri><p3><sg>
# 74               Narbe               scar  lernt/lernen<vblex><pri><p3><sg>
# 75               plump              plump  lernt/lernen<vblex><pri><p3><sg>
# 76          Aufenthalt               stay  lernt/lernen<vblex><pri><p3><sg>
# 77          schaukelte             rocked  lernt/lernen<vblex><pri><p3><sg>
# 78            Sehkraft           eyesight  lernt/lernen<vblex><pri><p3><sg>
# 79        unweigerlich         inevitably  lernt/lernen<vblex><pri><p3><sg>
# 80        mannigfachen           manifold  lernt/lernen<vblex><pri><p3><sg>
# 81           endgültig              final  lernt/lernen<vblex><pri><p3><sg>
# 82              hinken                lag  lernt/lernen<vblex><pri><p3><sg>
# 83             Willkür      arbitrariness  lernt/lernen<vblex><pri><p3><sg>
# 84              Umfang              scope  lernt/lernen<vblex><pri><p3><sg>
# 85             Abscheu            disgust  lernt/lernen<vblex><pri><p3><sg>
# 86             scheute             spared  lernt/lernen<vblex><pri><p3><sg>
# 87            Ohnmacht           fainting  lernt/lernen<vblex><pri><p3><sg>
# 88           tüchtigen          efficient  lernt/lernen<vblex><pri><p3><sg>
# 89          anstarrten            staring  lernt/lernen<vblex><pri><p3><sg>
# 90            ererbten          inherited  lernt/lernen<vblex><pri><p3><sg>
# 91           erzielten           achieved  lernt/lernen<vblex><pri><p3><sg>
# 92           verzehrte           consumed  lernt/lernen<vblex><pri><p3><sg>
# 93            Einwände         objections  lernt/lernen<vblex><pri><p3><sg>
# 94              söhnte         reconciled  lernt/lernen<vblex><pri><p3><sg>
# 95       verständigten             agreed  lernt/lernen<vblex><pri><p3><sg>
# 96         besänftigen            appease  lernt/lernen<vblex><pri><p3><sg>
# 97              wehren             defend  lernt/lernen<vblex><pri><p3><sg>
# 98              Zeiger            pointer  lernt/lernen<vblex><pri><p3><sg>
# 99         Ungewißheit        uncertainty  lernt/lernen<vblex><pri><p3><sg>
# 100         Munterkeit       cheerfulness  lernt/lernen<vblex><pri><p3><sg>
# 101           weigerte            refused  lernt/lernen<vblex><pri><p3><sg>
# 102             rührte            touched  lernt/lernen<vblex><pri><p3><sg>
#
#      history_seen  history_correct  session_seen  session_correct    p_pred
# 0              15             17.0             2              0.0  0.999900
# 1               4              5.0             1              0.0  0.023497
# 2               4              5.0             1              0.0  0.000100
# 3               2              3.0             2              1.0  0.999900
# 4               6              7.0             2              1.0  0.000100
# 5               6              7.0             1              0.0  0.004394
# 6               5              6.0             1              0.0  0.000100
# 7               4              5.0             1              0.0  0.000100
# 8               6              7.0             2              1.0  0.999900
# 9               3              4.0             1              0.0  0.001656
# 10              3              4.0             1              0.0  0.999900
# 11              3              4.0             4              3.0  0.999900
# 12              1              2.0             1              0.0  0.007931
# 13              4              5.0             1              0.0  0.000100
# 14              1              2.0             2              1.0  0.999900
# 15              2              3.0             2              1.0  0.999900
# 16              5              6.0             1              0.0  0.001213
# 17              3              4.0             3              2.0  0.000100
# 18              2              3.0             1              0.0  0.000100
# 19              3              4.0             1              0.0  0.003632
# 20              1              2.0             1              0.0  0.007047
# 21              1              0.0             2             -1.0  0.999900
# 22              1              2.0             2              1.0  0.999900
# 23              1              2.0             1              0.0  0.023437
# 24              1              2.0             1              0.0  0.004060
# 25              1              2.0             1              0.0  0.003329
# 26              1              2.0             2              1.0  0.999900
# 27              1              2.0             1              0.0  0.001548
# 28              1              2.0             2              1.0  0.999900
# 29              1              2.0             2              1.0  0.999900
# ..            ...              ...           ...              ...       ...
# 73              1              2.0             2              1.0  0.999900
# 74              1              2.0             1              0.0  0.001679
# 75              1              2.0             1              0.0  0.023567
# 76              4              3.0             2             -1.0  0.025782
# 77              2              3.0             2              1.0  0.024506
# 78              2              3.0             3              2.0  0.999900
# 79              1              2.0             2              1.0  0.999900
# 80              1              2.0             1              0.0  0.002277
# 81              1              2.0             2              1.0  0.999900
# 82              1              2.0             1              0.0  0.003801
# 83              5              5.0             1              0.0  0.000100
# 84              7              6.0             4              1.0  0.000100
# 85              7              6.0             3              0.0  0.000100
# 86              7              6.0             2             -1.0  0.000100
# 87             13             10.0             4             -1.0  0.000110
# 88              6              5.0             1              0.0  0.000100
# 89              3              3.0             1              0.0  0.000100
# 90              9              7.0             3              0.0  0.000100
# 91              9              7.0             1              0.0  0.000100
# 92              8              6.0             2             -1.0  0.000100
# 93             12              8.0             4             -1.0  0.000100
# 94              7              5.0             1              0.0  0.000100
# 95              7              5.0             2             -1.0  0.000100
# 96              9              6.0             3              0.0  0.000100
# 97              2              2.0             2              1.0  0.999900
# 98              2              2.0             1              0.0  0.000100
# 99              2              2.0             1              0.0  0.000100
# 100             2              2.0             1              0.0  0.001708
# 101             3              2.0             1              0.0  0.002237
# 102             3              2.0             2             -1.0  0.999900
#
# [103 rows x 14 columns]

# %%
lips.to_csv(lippath, index=False)

# %% [markdown]
# ### Check result

# %%
lips = pd.read_csv(lippath, index_col=False)
lips
# Out:
#      p_recall   timestamp   delta user_id learning_language ui_language  \
# 0    0.117647  1587891645  500746   pablo                de          en
# 1    0.200000  1587390899       0   pablo                de          en
# 2    0.200000  1587390899       0   pablo                de          en
# 3    0.666667  1587390899       0   pablo                de          en
# 4    0.285714  1587390899       0   pablo                de          en
# 5    0.142857  1587390899       0   pablo                de          en
# 6    0.166667  1587390899       0   pablo                de          en
# 7    0.200000  1587390899       0   pablo                de          en
# 8    0.285714  1587390899       0   pablo                de          en
# 9    0.250000  1587390899       0   pablo                de          en
# 10   0.250000  1587390899       0   pablo                de          en
# 11   1.000000  1587390899       0   pablo                de          en
# 12   0.500000  1587390899       0   pablo                de          en
# 13   0.200000  1587390899       0   pablo                de          en
# 14   1.000000  1587390899       0   pablo                de          en
# 15   0.666667  1587390899       0   pablo                de          en
# 16   0.166667  1587390899       0   pablo                de          en
# 17   0.750000  1587390899       0   pablo                de          en
# 18   0.333333  1587390899       0   pablo                de          en
# 19   0.250000  1587390899       0   pablo                de          en
# 20   0.500000  1587390899       0   pablo                de          en
# 21        inf  1587390899       0   pablo                de          en
# 22   1.000000  1587390899       0   pablo                de          en
# 23   0.500000  1587390899       0   pablo                de          en
# 24   0.500000  1587390899       0   pablo                de          en
# 25   0.500000  1587390899       0   pablo                de          en
# 26   1.000000  1587390899       0   pablo                de          en
# 27   0.500000  1587390899       0   pablo                de          en
# 28   1.000000  1587390899       0   pablo                de          en
# 29   1.000000  1587390899       0   pablo                de          en
# ..        ...         ...     ...     ...               ...         ...
# 73   1.000000  1587390899       0   pablo                de          en
# 74   0.500000  1587390899       0   pablo                de          en
# 75   0.500000  1587390899       0   pablo                de          en
# 76   0.666667  1587390899       0   pablo                de          en
# 77   0.666667  1587390899       0   pablo                de          en
# 78   1.000000  1587390899       0   pablo                de          en
# 79   1.000000  1587390899       0   pablo                de          en
# 80   0.500000  1587390899       0   pablo                de          en
# 81   1.000000  1587390899       0   pablo                de          en
# 82   0.500000  1587390899       0   pablo                de          en
# 83   0.200000  1587390899       0   pablo                de          en
# 84   0.666667  1587390899       0   pablo                de          en
# 85   0.500000  1587390899       0   pablo                de          en
# 86   0.333333  1587390899       0   pablo                de          en
# 87   0.400000  1587390899       0   pablo                de          en
# 88   0.200000  1587390899       0   pablo                de          en
# 89   0.333333  1587390899       0   pablo                de          en
# 90   0.428571  1587390899       0   pablo                de          en
# 91   0.142857  1587390899       0   pablo                de          en
# 92   0.333333  1587390899       0   pablo                de          en
# 93   0.500000  1587390899       0   pablo                de          en
# 94   0.200000  1587390899       0   pablo                de          en
# 95   0.400000  1587390899       0   pablo                de          en
# 96   0.500000  1587390899       0   pablo                de          en
# 97   1.000000  1587390899       0   pablo                de          en
# 98   0.500000  1587390899       0   pablo                de          en
# 99   0.500000  1587390899       0   pablo                de          en
# 100  0.500000  1587390899       0   pablo                de          en
# 101  0.500000  1587390899       0   pablo                de          en
# 102  1.000000  1587390899       0   pablo                de          en
#
#                word_ll            word_ul                     lexeme_string  \
# 0             approved           billigte  lernt/lernen<vblex><pri><p3><sg>
# 1         indifference   Gleichgültigkeit  lernt/lernen<vblex><pri><p3><sg>
# 2               vermin         Ungeziefer  lernt/lernen<vblex><pri><p3><sg>
# 3              sleeves              Ärmel  lernt/lernen<vblex><pri><p3><sg>
# 4                 sobs         Schluchzen  lernt/lernen<vblex><pri><p3><sg>
# 5            flickered         flimmerten  lernt/lernen<vblex><pri><p3><sg>
# 6           disengaged         ausgerückt  lernt/lernen<vblex><pri><p3><sg>
# 7                  sob         schluchzen  lernt/lernen<vblex><pri><p3><sg>
# 8                edges            Rändern  lernt/lernen<vblex><pri><p3><sg>
# 9          communicate       verständigen  lernt/lernen<vblex><pri><p3><sg>
# 10               crash              Krach  lernt/lernen<vblex><pri><p3><sg>
# 11   rationalarguments    Vernunftgründen  lernt/lernen<vblex><pri><p3><sg>
# 12            work-shy      arbeitsscheue  lernt/lernen<vblex><pri><p3><sg>
# 13         As a result      0.0olgedessen  lernt/lernen<vblex><pri><p3><sg>
# 14           obstinacy          Eigensinn  lernt/lernen<vblex><pri><p3><sg>
# 15            indetail        ausführlich  lernt/lernen<vblex><pri><p3><sg>
# 16           gradually         allmählich  lernt/lernen<vblex><pri><p3><sg>
# 17          stiffeners      Versteifungen  lernt/lernen<vblex><pri><p3><sg>
# 18         Windowsheet       Fensterblech  lernt/lernen<vblex><pri><p3><sg>
# 19            deserved           gebührte  lernt/lernen<vblex><pri><p3><sg>
# 20               tired        überdrüssig  lernt/lernen<vblex><pri><p3><sg>
# 21             Despite              Trotz  lernt/lernen<vblex><pri><p3><sg>
# 22            dispense          entbehren  lernt/lernen<vblex><pri><p3><sg>
# 23               angry             wütend  lernt/lernen<vblex><pri><p3><sg>
# 24            backbone           Rückgrat  lernt/lernen<vblex><pri><p3><sg>
# 25              Kiefer             Kiefer  lernt/lernen<vblex><pri><p3><sg>
# 26          endangered          gefährdet  lernt/lernen<vblex><pri><p3><sg>
# 27     faintingsimilar  ohnmachtähnlichen  lernt/lernen<vblex><pri><p3><sg>
# 28          protection           Schonung  lernt/lernen<vblex><pri><p3><sg>
# 29            reserved        vorbehalten  lernt/lernen<vblex><pri><p3><sg>
# ..                 ...                ...                               ...
# 73       impracticable     undurchführbar  lernt/lernen<vblex><pri><p3><sg>
# 74                scar              Narbe  lernt/lernen<vblex><pri><p3><sg>
# 75               plump              plump  lernt/lernen<vblex><pri><p3><sg>
# 76                stay         Aufenthalt  lernt/lernen<vblex><pri><p3><sg>
# 77              rocked         schaukelte  lernt/lernen<vblex><pri><p3><sg>
# 78            eyesight           Sehkraft  lernt/lernen<vblex><pri><p3><sg>
# 79          inevitably       unweigerlich  lernt/lernen<vblex><pri><p3><sg>
# 80            manifold       mannigfachen  lernt/lernen<vblex><pri><p3><sg>
# 81               final          endgültig  lernt/lernen<vblex><pri><p3><sg>
# 82                 lag             hinken  lernt/lernen<vblex><pri><p3><sg>
# 83       arbitrariness            Willkür  lernt/lernen<vblex><pri><p3><sg>
# 84               scope             Umfang  lernt/lernen<vblex><pri><p3><sg>
# 85             disgust            Abscheu  lernt/lernen<vblex><pri><p3><sg>
# 86              spared            scheute  lernt/lernen<vblex><pri><p3><sg>
# 87            fainting           Ohnmacht  lernt/lernen<vblex><pri><p3><sg>
# 88           efficient          tüchtigen  lernt/lernen<vblex><pri><p3><sg>
# 89             staring         anstarrten  lernt/lernen<vblex><pri><p3><sg>
# 90           inherited           ererbten  lernt/lernen<vblex><pri><p3><sg>
# 91            achieved          erzielten  lernt/lernen<vblex><pri><p3><sg>
# 92            consumed          verzehrte  lernt/lernen<vblex><pri><p3><sg>
# 93          objections           Einwände  lernt/lernen<vblex><pri><p3><sg>
# 94          reconciled             söhnte  lernt/lernen<vblex><pri><p3><sg>
# 95              agreed      verständigten  lernt/lernen<vblex><pri><p3><sg>
# 96             appease        besänftigen  lernt/lernen<vblex><pri><p3><sg>
# 97              defend             wehren  lernt/lernen<vblex><pri><p3><sg>
# 98             pointer             Zeiger  lernt/lernen<vblex><pri><p3><sg>
# 99         uncertainty        Ungewißheit  lernt/lernen<vblex><pri><p3><sg>
# 100       cheerfulness         Munterkeit  lernt/lernen<vblex><pri><p3><sg>
# 101            refused           weigerte  lernt/lernen<vblex><pri><p3><sg>
# 102            touched             rührte  lernt/lernen<vblex><pri><p3><sg>
#
#      history_seen  history_correct  session_seen  session_correct    p_pred
# 0              15             17.0             2              0.0  0.999900
# 1               4              5.0             1              0.0  0.023497
# 2               4              5.0             1              0.0  0.000100
# 3               2              3.0             2              1.0  0.999900
# 4               6              7.0             2              1.0  0.000100
# 5               6              7.0             1              0.0  0.004394
# 6               5              6.0             1              0.0  0.000100
# 7               4              5.0             1              0.0  0.000100
# 8               6              7.0             2              1.0  0.999900
# 9               3              4.0             1              0.0  0.001656
# 10              3              4.0             1              0.0  0.999900
# 11              3              4.0             4              3.0  0.999900
# 12              1              2.0             1              0.0  0.007931
# 13              4              5.0             1              0.0  0.000100
# 14              1              2.0             2              1.0  0.999900
# 15              2              3.0             2              1.0  0.999900
# 16              5              6.0             1              0.0  0.001213
# 17              3              4.0             3              2.0  0.000100
# 18              2              3.0             1              0.0  0.000100
# 19              3              4.0             1              0.0  0.003632
# 20              1              2.0             1              0.0  0.007047
# 21              1              0.0             2             -1.0  0.999900
# 22              1              2.0             2              1.0  0.999900
# 23              1              2.0             1              0.0  0.023437
# 24              1              2.0             1              0.0  0.004060
# 25              1              2.0             1              0.0  0.003329
# 26              1              2.0             2              1.0  0.999900
# 27              1              2.0             1              0.0  0.001548
# 28              1              2.0             2              1.0  0.999900
# 29              1              2.0             2              1.0  0.999900
# ..            ...              ...           ...              ...       ...
# 73              1              2.0             2              1.0  0.999900
# 74              1              2.0             1              0.0  0.001679
# 75              1              2.0             1              0.0  0.023567
# 76              4              3.0             2             -1.0  0.025782
# 77              2              3.0             2              1.0  0.024506
# 78              2              3.0             3              2.0  0.999900
# 79              1              2.0             2              1.0  0.999900
# 80              1              2.0             1              0.0  0.002277
# 81              1              2.0             2              1.0  0.999900
# 82              1              2.0             1              0.0  0.003801
# 83              5              5.0             1              0.0  0.000100
# 84              7              6.0             4              1.0  0.000100
# 85              7              6.0             3              0.0  0.000100
# 86              7              6.0             2             -1.0  0.000100
# 87             13             10.0             4             -1.0  0.000110
# 88              6              5.0             1              0.0  0.000100
# 89              3              3.0             1              0.0  0.000100
# 90              9              7.0             3              0.0  0.000100
# 91              9              7.0             1              0.0  0.000100
# 92              8              6.0             2             -1.0  0.000100
# 93             12              8.0             4             -1.0  0.000100
# 94              7              5.0             1              0.0  0.000100
# 95              7              5.0             2             -1.0  0.000100
# 96              9              6.0             3              0.0  0.000100
# 97              2              2.0             2              1.0  0.999900
# 98              2              2.0             1              0.0  0.000100
# 99              2              2.0             1              0.0  0.000100
# 100             2              2.0             1              0.0  0.001708
# 101             3              2.0             1              0.0  0.002237
# 102             3              2.0             2             -1.0  0.999900
#
# [103 rows x 14 columns]

# %% [markdown]
# ## Design accurate correction function

# %%
import sys
sys.path.append('../pyGUI//')

from kivy_multipleAnswer import *
# Out:
# [INFO   ] [Logger      ] Record log in /Users/pabloherrero/.kivy/logs/kivy_20-05-02_0.txt
# [2020-05-02 16:21:13,609] {/Users/pabloherrero/anaconda3/lib/python3.7/site-packages/kivy/logger.py:194} INFO - [Logger      ] Record log in /Users/pabloherrero/.kivy/logs/kivy_20-05-02_0.txt
# [INFO   ] [Kivy        ] v1.11.1
# [2020-05-02 16:21:13,607] {/Users/pabloherrero/anaconda3/lib/python3.7/site-packages/kivy/__init__.py:475} INFO - [Kivy        ] v1.11.1
# [INFO   ] [Kivy        ] Installed at "/Users/pabloherrero/anaconda3/lib/python3.7/site-packages/kivy/__init__.py"
# [2020-05-02 16:21:13,617] {/Users/pabloherrero/anaconda3/lib/python3.7/site-packages/kivy/__init__.py:478} INFO - [Kivy        ] Installed at "/Users/pabloherrero/anaconda3/lib/python3.7/site-packages/kivy/__init__.py"
# [INFO   ] [Python      ] v3.7.1 (default, Dec 14 2018, 13:28:58)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# [2020-05-02 16:21:13,621] {/Users/pabloherrero/anaconda3/lib/python3.7/site-packages/kivy/__init__.py:479} INFO - [Python      ] v3.7.1 (default, Dec 14 2018, 13:28:58)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# [INFO   ] [Python      ] Interpreter at "/Users/pabloherrero/anaconda3/bin/python"
# [2020-05-02 16:21:13,625] {/Users/pabloherrero/anaconda3/lib/python3.7/site-packages/kivy/__init__.py:480} INFO - [Python      ] Interpreter at "/Users/pabloherrero/anaconda3/bin/python"
# [INFO   ] [Factory     ] 184 symbols loaded
# [2020-05-02 16:21:13,723] {/Users/pabloherrero/anaconda3/lib/python3.7/site-packages/kivy/factory.py:170} INFO - [Factory     ] 184 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_imageio, img_dds, img_sdl2, img_pil, img_gif (img_ffpyplayer ignored)
# [2020-05-02 16:21:14,150] {/Users/pabloherrero/anaconda3/lib/python3.7/site-packages/kivy/core/__init__.py:149} INFO - [Image       ] Providers: img_tex, img_imageio, img_dds, img_sdl2, img_pil, img_gif (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [2020-05-02 16:21:14,266] {/Users/pabloherrero/anaconda3/lib/python3.7/site-packages/kivy/core/__init__.py:69} INFO - [Text        ] Provider: sdl2

# %%
qu, answ, iqu = set_question(lippath)
qu, answ
# Out:
# ('ausgerückt', 'disengaged')

# %% [markdown]
# ##### Let's say the question is to translate "edges" : "Rändern"
# We need to forgive plural formation, capitalization and accentuation errors
#
# So rand, ränder, rander, should in principle be valid, then we may want to impose some grammatical rules

# %%
answ, qu = ('Rändern', 'edges')

# %%
lipstick = pd.read_csv(lippath)
lipstick.set_index('word_ul', inplace=True, drop=False)
lipstick.loc[answ]
# Out:
# p_recall                                      1.08333
# timestamp                                 1.58827e+09
# delta                                          878427
# user_id                                         pablo
# learning_language                                  de
# ui_language                                        en
# word_ll                                    ausgerückt
# word_ul                                    disengaged
# lexeme_string        lernt/lernen<vblex><pri><p3><sg>
# history_seen                                       12
# history_correct                                    13
# session_seen                                        1
# session_correct                                     0
# p_pred                                         0.0001
# Name: disengaged, dtype: object

# %%
lipstick.loc[answ, 'learning_language']
# Out:
# 'de'

# %% [markdown]
# ### Let's start supposing the plural form and the dativ declination are correct, but punctuation and (obviously) capitalization don't coincide

# %%
myansw = 'randern'  # This would be the input

# %%
answ == myansw
# Out:
# False

# %%
accented_string.lower(), answ.lower()
# Out:
# ('málaga', 'rändern')

# %%
import unicodedata
accented_string = u'Málaga'
# accented_string is of type 'unicode'
def strip_accents(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn')
filtansw = strip_accents(answ.lower())
filtansw
# Out:
# 'randern'

# %%
filtansw == myansw
# Out:
# True

# %% [markdown]
# ### Now let's be totally permissive: look for coincidence only in lexeme baseform

# %%
myansw = 'rand'

# %%
anAnsw = apertium.analyze('de', answ)
baseAnsw = anAnsw[0].readings[0][0].baseform
anAnsw[0].readings[0][0], anAnsw[0].wordform, baseAnsw
# Out:
# (SReading(baseform='Rand', tags=['n', 'm', 'pl', 'dat']), 'Rändern', 'Rand')

# %%
baseAnsw = strip_accents(baseAnsw.lower())
baseAnsw
# Out:
# 'rand'

# %%
anInput = apertium.analyze('de', myansw)
baseInput = anInput[0].readings[0][0].baseform
anInput[0].readings[0][0], anInput[0].wordform, baseInput
# Out:
# (SReading(baseform='rand', tags=['n', 'm', 'sg', 'nom', 'lower']),
#  'rand',
#  'rand')

# %%
baseInput = strip_accents(baseInput.lower())
baseInput
# Out:
# 'rand'

# %%
baseInput == baseAnsw
# Out:
# True

# %% [markdown]
# ### Last but not least: let's only accept the plural form, disregard accents

# %%
myansw = 'rander'

# %%
baseAnsw
# Out:
# 'rand'

# %%
anAnsw
# Out:
# [Rändern/Rand<n><m><pl><dat>/rand<n><m><pl><dat><lower>/rand<n><m><pl><dat><lower>]

# %%
apertium.tagger.tag('de', 'Rand')
# Out:
# [Rand/Rand<n><m><sg><nom>/Rand<n><m><sg><dat>/Rand<n><m><sg><acc>]

# %%
gen = apertium.Generator('en')
gen.generate('^edge<n><pl>$')
# Out:
# 'edges'

# %%
apertium.

# %%
g = apertium.Generator('en')
g.generate('^cat<n><pl>$')
# Out:
# 'cats'

# %%
t = apertium.Tagger('en')
t.tag('The cat is walking')
apertium.Tagger
# Out:
# [The/The<det><def><sp>,
#  cat/cat<n><sg>,
#  is/be<vbser><pres><p3><sg>,
#  walking/walk<vblex><ger>]
