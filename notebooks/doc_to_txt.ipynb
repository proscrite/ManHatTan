# %%
import docx 
from io import StringIO

# %% [markdown]
# # Import file

# %%
from docx import Document

# %%
doc = docx.Document('Notes from _Justine_.docx')

# %% [markdown]
# ## Read its content: tables of one cell

# %%
for t in doc.tables:
    for r in t.rows:
        for c in r.cells:
            print(c.text)
# Out:
# Justine
# Durrell Lawrence
# This document is overwritten when you make changes in Play Books.
# You should make a copy of this document before you edit it.

# %%
cell = doc.tables[3].rows[0].cells[0]
text = cell.text
cell.paragraphs[1].style.font
# Document.paragraphs.style.font

# %% [markdown]
# ## Find words highlighted in blue: there is no python interface, need to access xml
# By modifying https://stackoverflow.com/questions/9562671/extracting-highlighted-words-from-word-document-docx-in-python?rq=1
#
# Structure of a filled text:
# ```
# <w:r>
#     <w:rPr>
#         <w:shd w:fill='fde096'> #In this case gold
#     </w:rPr>
#     <w:t> text that is highlighted </w:t>
# </w:r>```

# %%
#!usr/bin/python
# -*- coding: utf-8 -*-
from docx import *
document = docx.Document(r'Notes from _Justine_.docx')
words = document.element.xpath('//w:r')#, namespaces=document._element.nsmap)
# words = etree.ElementBase.xpath(para._element, '//w:r', 
#                                         namespaces=para._element.nsmap)
WPML_URI = "{http://schemas.openxmlformats.org/wordprocessingml/2006/main}"
tag_rPr = WPML_URI + 'rPr'
tag_highlight = 'w:shd'
tag_val = WPML_URI + 'fill'
tag_t = WPML_URI + 't'
gold = []
blue = []
orange = []

for word in words:
    for rPr in word.findall(tag_rPr):
        high=rPr.xpath(tag_highlight)
        for hi in high:
            print(hi.attrib[tag_val])
            if hi.attrib[tag_val] == 'fde096': 
                gold.append(word.find(tag_t).text.lower())
            elif hi.attrib[tag_val] == 'ffb8a1':
                orange.append(word.find(tag_t).text.lower())
            elif hi.attrib[tag_val] == '93e3ed':
                blue.append(word.find(tag_t).text.lower())
# Out:
# auto
# 93e3ed
# fde096
# fde096
# ffb8a1
# ffb8a1
# c5e1a5
# c5e1a5
# 93e3ed
# ffb8a1
# 93e3ed
# fde096
# ffb8a1
# fde096
# ffb8a1
# ffb8a1
# c5e1a5
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# 93e3ed
# ffb8a1
# ffb8a1
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# ffb8a1
# 93e3ed
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# 93e3ed
# 93e3ed
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# 93e3ed
# ffb8a1
# 93e3ed
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# fde096
# 93e3ed
# fde096
# fde096
# ffb8a1
# 93e3ed
# 93e3ed
# ffb8a1
# 93e3ed
# 93e3ed
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# 93e3ed
# 93e3ed
# 93e3ed
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# ffb8a1
# 93e3ed
# 93e3ed
# 93e3ed
# ffb8a1
# 93e3ed
# 93e3ed
# ffb8a1
# ffb8a1
# ffb8a1
# fde096
# ffb8a1
# c5e1a5
# 93e3ed
# fde096
# 93e3ed
# ffb8a1
# 93e3ed
# c5e1a5
# 93e3ed
# fde096
# 93e3ed
# fde096
# c5e1a5
# c5e1a5
# 93e3ed
# 93e3ed
# 93e3ed
# c5e1a5
# fde096
# c5e1a5
# 93e3ed
# 93e3ed
# ffb8a1
# ffb8a1
# 93e3ed
# ffb8a1
# c5e1a5
# 93e3ed
# c5e1a5
# ffb8a1
# 93e3ed
# fde096
# c5e1a5
# 93e3ed
# 93e3ed
# c5e1a5
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# ffb8a1
# ffb8a1
# fde096
# 93e3ed
# 93e3ed
# ffb8a1
# ffb8a1
# fde096
# fde096
# 93e3ed
# 93e3ed
# fde096
# 93e3ed
# ffb8a1
# ffb8a1
# ffb8a1
# fde096
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# fde096
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# 93e3ed
# c5e1a5
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# ffb8a1
# 93e3ed
# 93e3ed
# fde096
# ffb8a1
# 93e3ed
# fde096
# c5e1a5
# c5e1a5
# 93e3ed
# 93e3ed
# fde096
# ffb8a1
# fde096

# %% [markdown]
# ## Organize words by color in dataframe

# %%
import pandas as pd

df = pd.DataFrame([gold, blue, orange]).T
df.columns =['gold', 'blue', 'orange']
df
# Out:
#                                                  gold  \
# 0                                         dauntlessly
# 1                                             debauch
# 2   region where the flesh, stripped by over-indul...
# 3                                            plotinus
# 4   balthazar says that the natural traitors — lik...
# 5   it is a mystery how he can have, suspended fro...
# 6   one of those rare people who had found a philo...
# 7   there was something exhausting and perverting ...
# 8   'if you think of yourself as a sleeping city f...
# 9   like women who think by biological precept and...
# 10  truth is that he had been seized by the vertig...
# 11  meanwhile' as nessim was to say in those gentl...
# 12  each stage of development each man resumes the...
# 13  we have proved the bonds of friendship stronge...
# 14  this, t realized with horror, was the hold i n...
# 15  for loving is only a sort of skin-language, se...
# 16  justine loved me because i presented to her so...
# 17  loving is so much truer when sympathy and not ...
# 18          every kiss is the conquest of a repulsion
# 19                      please don't make love to me.
# 20  i catch myself thinking, to italy perhaps or t...
# 21  humility! the last trap that awaits the ego in...
# 22  pursewarden on the 'n-dimensional novel' trilo...
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# ..                                                ...
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
# 59                                               None
# 60                                               None
# 61                                               None
# 62                                               None
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
# 73                                               None
# 74                                               None
#
#                                                  blue  \
# 0   the city which used us as its flora— precipita...
# 1                                              strops
# 2                                             groping
# 3                                            exiguous
# 4                                            crockery
# 5                                              relish
# 6                                              affray
# 7                                             demotic
# 8                                               ample
# 9                                          diffidence
# 10                                         foundering
# 11                                              dowry
# 12                                             pander
# 13                                            forbear
# 14                                            languor
# 15                                       despondently
# 16                                           lethargy
# 17                                          desultory
# 18                                             marrow
# 19                                           wallowed
# 20                                              regal
# 21                                             gouged
# 22                                             gloats
# 23                                               ekes
# 24                                             limpet
# 25                                          starboard
# 26                                          anchorite
# 27                                          anchorite
# 28                                           heirloom
# 29                                           slipshod
# ..                                                ...
# 45                                            nettles
# 46                                           steeples
# 47                                          scrimmage
# 48                                              nooks
# 49                                             gables
# 50                                             wraith
# 51                                         foundering
# 52                                         bequeathed
# 53                                        beleaguered
# 54                                            groping
# 55                                        perfunctory
# 56                                           exegesis
# 57                                              stout
# 58                                          festooned
# 59                                        deerstalker
# 60                                           hassocks
# 61                                             flurry
# 62                                             divest
# 63                                          desultory
# 64                                               punt
# 65                                              lithe
# 66                                             sodden
# 67                                                eke
# 68                                              lodge
# 69                                         chaffering
# 70                                            fording
# 71                                           downpour
# 72                                           paroxysm
# 73                                          emollient
# 74                                         diffidence
#
#                                                orange
# 0                                             donnish
# 1   nor can i say that she harmed nobody. but thos...
# 2   capodistria has the purely involuntary knack o...
# 3   that there should be something free, something...
# 4   we are the children of our landscape; it dicta...
# 5   game of thought; for you thought is a weapon, ...
# 6   on a rotting sofa in one corner of the room, m...
# 7   all this i have come to regard as a sort of ov...
# 8   i lay with half-shut eyes while justine (how c...
# 9   i would not mistake it for gluttony or self-in...
# 10  have something to learn from each other. what ...
# 11  the whole of the scene which we had just enact...
# 12  i saw then what i should have seen long before...
# 13  where the carrion is' she once quoted proudly ...
# 14  almost exactly expresses the curiously ingrown...
# 15  'idle' she writes 'to imagine falling in love ...
# 16  these are the moments which are not calculable...
# 17  pursewarden could afford to be convivial and a...
# 18  and surprised me by a gallantry to which my li...
# 19  at this she put out her hand and placed it on ...
# 20  a city becomes a world when one loves one of i...
# 21                                        inhabitants
# 22  'tell the consul-general' i said ... and utter...
# 23  'the women of the foreign communities here are...
# 24  she gave herself to me with such contempt that...
# 25  she gave me the impression of someone engaged ...
# 26  it was never her betrayals that upset me — for...
# 27                          women must attack writers
# 28  hunger for information, for power through self...
# 29  'life, the raw material, is only lived in pote...
# ..                                                ...
# 45  its function to help us deliberate on the nove...
# 46  realize that each person can only claim one as...
# 47  only the thinnest integument separates his smi...
# 48  love is horribly stable, and each of us is onl...
# 49  justine always reminded me of a somnambulist d...
# 50  but by some curious paradox it was these very ...
# 51  but as if the physical contact could ease the ...
# 52  has come to represent what she calls her noble...
# 53  god's real and subtle nature must be clear of ...
# 54  justine was merely working out with me the sam...
# 55      . it was not based on any repose of the will.
# 56  he was only to be seen now through the distort...
# 57  they overlapped reality and interrupted his wa...
# 58  strangely enough i thought of it not as a pers...
# 59  i was filled no longer with despairing self-pi...
# 60  my own, charged with every presage of disaster...
# 61  in art i had failed (it suddenly occurred to m...
# 62        monsieur, je suis devenue la solitude même'
# 63         we who have travelled much and loved much:
# 64  only we appreciate the complexities of tendern...
# 65               blame not the bearer of ill tidings'
# 66  ' he says in a small conciliatory voice: 'mast...
# 67  the scene in moeurs where he tries to read her...
# 68  somewhere in the heart of experience there is ...
# 69  attentive enough, loving enough, or patient en...
# 70  never doubt it. get well, melissa, you must ge...
# 71  with the posting of this letter of acceptance ...
# 72  time carries us forward by the momentum of tho...
# 73                                               None
# 74                                               None
#
# [75 rows x 3 columns]

# %% [markdown]
# ## Export dataframe

# %%
df.to_csv('/Users/pabloherrero/Documents/ManHatTan/Notes_from_Justine_.out' )

# %% [markdown]
# # Write a 'Hello world!' run and higlight it in yellow

# %%
from docx.enum.text import WD_COLOR_INDEX
doc = docx.Document()
p = doc.add_paragraph()
run = p.add_run('Hello world!')
run.font.highlight_color = WD_COLOR_INDEX.YELLOW
run.font.highlight_color
# Out:
# 7

# %%
doc.save('helloworld.docx')

# %% [markdown]
# ## Read back hello world file and display style

# %%
doc = docx.Document(f'helloworld.docx')
p = doc.paragraphs[0].runs[0]

# %%
p.font.highlight_color
# Out:
# 7

# %%
print(p)
# Out:
# <docx.text.run.Run object at 0x111358518>

# %%
if p.font.highlight_color == 7:
    print('True')
# Out:
# True

# %% [markdown]
# # Others

# %% [markdown]
# ## Classify by font name

# %%
len(doc.tables), len(doc.paragraphs)
para = doc.tables[4].rows[0].cells[0].paragraphs
text = doc.tables[4].rows[0].cells[0].text
for p in para: 
    print(p.runs)
    for r in p.runs:
        print(r.text, r.font.name)
# Out:
# []
# [<docx.text.run.Run object at 0x11b06a278>]
#  None
# []
# [<docx.text.run.Run object at 0x11b06a2e8>]
# debauch Verdana
# []
# [<docx.text.run.Run object at 0x11b06a320>]
# January 17, 2019 Roboto
# [<docx.text.run.Run object at 0x11b06a978>, <docx.text.run.Run object at 0x11b06a358>, <docx.text.run.Run object at 0x11b06a470>, <docx.text.run.Run object at 0x11b06a940>, <docx.text.run.Run object at 0x11b06a438>, <docx.text.run.Run object at 0x11b06a4e0>]
#  None
#  None
#  None
# 16 None
#  None
#  None

# %% [markdown]
# #####  This way we can find different fonts: verdana, roboto...

# %% [markdown]
# ## Basic way to understand the fill classifying method

# %%
from docx import settings
doc = Document(r'Copia_Notes_from_Justine_.docx', )

words = doc.element.xpath('//w:rPr') # //w:shd to access shaded (background colored) runs
len(words), type(words[0])
# Out:
# (80, docx.oxml.text.font.CT_RPr)

# %%
res = []
for word in words:
    results = word.xpath('w:shd')
    if results != []:
        res.append(results[0].get(qn('w:fill')))
#     text = word.find(WPML_URI + 't')
res, text
# Out:
# (['93e3ed',
#   '93e3ed',
#   '93e3ed',
#   'fde096',
#   'fde096',
#   'fde096',
#   'fde096',
#   'fde096',
#   'fde096',
#   'ffb8a1',
#   'ffb8a1',
#   'ffb8a1'],
#  None)

# %%
words2 = document.element.xpath('//w:r')
for word in words2:
    if word.find(WPML_URI+'t') != None:
        print(word.find(WPML_URI+'t').text)
# Out:
# This document is overwritten when you make changes in Play Books.
# You should make a copy of this document before you edit it.
# 131 notes/highlights
# Created by Pablo Herrero
#
#  –
# Last synced June 3, 2019
# Start
# the city which used us as its flora
# —
# precipitated in us conflicts which were hers and which we mistook for our own: beloved Alexandria!
# January 7, 2019
# 4
# dauntlessly
# January 15, 2019
# 9
# debauch
# January 17, 2019
# 16
# donnish
# January 20, 2019
# 19
